# %%
# maths library for matrix manipulation
import numpy as np

# matplotlib is a library for plotting things inside Python
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
# This is a library for reading and writing image files

from skimage import io

# %%
# a library for finding files
from scipy.spatial import distance
from sklearn import decomposition
import glob

# %%
JPGList = glob.glob('/home/impett/Downloads/Annunc2/AnnuncsJun18/*/*.jpg')

# %%
len(JPGList)
# Out:
# 505

# %%
allList = JPGList #[:100]

# %%
# allList is the list of all image file names

len(allList)
# Out:
# 505

# %%
from skimage import feature

# %%
from skimage import transform

# %%
import tqdm

# %%
import pickle

# %%
from scipy.spatial import distance

# %%
n_components = 50
# ipca = decomposition.IncrementalPCA(n_components=n_components, batch_size=100)

# %%
ipca = pickle.load( open( "hog-pca.p", "rb" ) )

# %%
L = len(allList)
imf = np.zeros((L*100,n_components))

# %%
imCrops = []
k = 0

for fileName in tqdm.tqdm(allList):
    im = io.imread(fileName)
    
    for j in range(100):
        myshape = np.shape(im)
        w = myshape[0]
        h = myshape[1]
        maxHeight = np.min([w,h])
        size = np.random.randint(low=50,high=np.min([maxHeight,150]))
        minw = np.random.randint(w - size)
        maxw = np.random.randint(h - size)

        newim = im[minw:minw+size,maxw:maxw+size,:]
        imr = transform.resize(newim,(256,256))
#         allImageSections.append(imr)
        F = feature.hog(imr,  pixels_per_cell=(16,16)  )
#         imageFeatureSections.append(F)
        imCrops.append([fileName, minw,minw+size,maxw,maxw+size])
        imf[k,:] = ipca.transform(F.reshape(1,-1))
        k += 1
# Out:
#   0%|          | 0/505 [00:00<?, ?it/s]/home/impett/anaconda3/envs/esu2018/lib/python3.5/site-packages/skimage/transform/_warps.py:105: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/impett/anaconda3/envs/esu2018/lib/python3.5/site-packages/skimage/transform/_warps.py:110: UserWarning: Anti-aliasing will be enabled by default in skimage 0.15 to avoid aliasing artifacts when down-sampling images.
#   warn("Anti-aliasing will be enabled by default in skimage 0.15 to "
# /home/impett/anaconda3/envs/esu2018/lib/python3.5/site-packages/skimage/feature/_hog.py:150: skimage_deprecation: Default value of `block_norm`==`L1` is deprecated and will be changed to `L2-Hys` in v0.15. To supress this message specify explicitly the normalization method.
#   skimage_deprecation)
#
#   0%|          | 1/505 [00:02<22:59,  2.74s/it]
#   0%|          | 2/505 [00:05<23:12,  2.77s/it]
#   1%|          | 3/505 [00:08<23:04,  2.76s/it]
#   1%|          | 4/505 [00:11<23:18,  2.79s/it]
#   1%|          | 5/505 [00:14<23:37,  2.83s/it]
#   1%|          | 6/505 [00:17<24:15,  2.92s/it]
#   1%|▏         | 7/505 [00:20<24:23,  2.94s/it]
#   2%|▏         | 8/505 [00:24<24:58,  3.02s/it]
#   2%|▏         | 9/505 [00:27<25:09,  3.04s/it]
#   2%|▏         | 10/505 [00:30<25:20,  3.07s/it]
#   2%|▏         | 11/505 [00:34<25:28,  3.10s/it]
#   2%|▏         | 12/505 [00:37<25:42,  3.13s/it]
#   3%|▎         | 13/505 [00:41<25:54,  3.16s/it]
#   3%|▎         | 14/505 [00:44<25:59,  3.18s/it]
#   3%|▎         | 15/505 [00:48<26:26,  3.24s/it]
#   3%|▎         | 16/505 [00:52<26:34,  3.26s/it]
#   3%|▎         | 17/505 [00:55<26:36,  3.27s/it]
#   4%|▎         | 18/505 [00:59<26:42,  3.29s/it]
#   4%|▍         | 19/505 [01:02<26:38,  3.29s/it]
#   4%|▍         | 20/505 [01:05<26:35,  3.29s/it]
#  52%|█████▏    | 261/505 [12:24<11:36,  2.85s/it]
#  52%|█████▏    | 262/505 [12:27<11:33,  2.85s/it]
#  52%|█████▏    | 263/505 [12:30<11:30,  2.85s/it]
#  52%|█████▏    | 264/505 [12:33<11:28,  2.86s/it]
#  52%|█████▏    | 265/505 [12:36<11:25,  2.86s/it]
#  53%|█████▎    | 266/505 [12:40<11:23,  2.86s/it]
#  53%|█████▎    | 267/505 [12:43<11:20,  2.86s/it]
#  53%|█████▎    | 268/505 [12:46<11:17,  2.86s/it]
#  53%|█████▎    | 269/505 [12:50<11:15,  2.86s/it]
#  53%|█████▎    | 270/505 [12:53<11:13,  2.86s/it]
#  54%|█████▎    | 271/505 [12:56<11:10,  2.87s/it]
#  54%|█████▍    | 272/505 [12:59<11:07,  2.87s/it]
#  54%|█████▍    | 273/505 [13:02<11:05,  2.87s/it]
#  54%|█████▍    | 274/505 [13:05<11:02,  2.87s/it]
#  54%|█████▍    | 275/505 [13:08<10:59,  2.87s/it]
#  55%|█████▍    | 276/505 [13:10<10:56,  2.87s/it]
#  55%|█████▍    | 277/505 [13:13<10:53,  2.87s/it]
#  55%|█████▌    | 278/505 [13:16<10:50,  2.87s/it]
#  55%|█████▌    | 279/505 [13:19<10:47,  2.87s/it]
#  55%|█████▌    | 280/505 [13:22<10:44,  2.87s/it]
#  56%|█████▌    | 281/505 [13:25<10:41,  2.87s/it]
#  56%|█████▌    | 282/505 [13:28<10:39,  2.87s/it]
#  56%|█████▌    | 283/505 [13:31<10:36,  2.87s/it]
#  56%|█████▌    | 284/505 [13:35<10:34,  2.87s/it]
#  56%|█████▋    | 285/505 [13:38<10:31,  2.87s/it]
#  57%|█████▋    | 286/505 [13:42<10:30,  2.88s/it]
#  57%|█████▋    | 287/505 [13:45<10:27,  2.88s/it]
#  57%|█████▋    | 288/505 [13:48<10:24,  2.88s/it]
#  57%|█████▋    | 289/505 [13:51<10:21,  2.88s/it]
#  57%|█████▋    | 290/505 [13:54<10:18,  2.88s/it]
#  58%|█████▊    | 291/505 [13:56<10:15,  2.88s/it]
#  58%|█████▊    | 292/505 [13:59<10:12,  2.88s/it]
#  58%|█████▊    | 293/505 [14:03<10:10,  2.88s/it]
#  58%|█████▊    | 294/505 [14:06<10:07,  2.88s/it]
#  58%|█████▊    | 295/505 [14:09<10:04,  2.88s/it]
#  59%|█████▊    | 296/505 [14:12<10:01,  2.88s/it]
#  59%|█████▉    | 297/505 [14:14<09:58,  2.88s/it]
#  59%|█████▉    | 298/505 [14:17<09:55,  2.88s/it]
#  59%|█████▉    | 299/505 [14:20<09:52,  2.88s/it]
#  59%|█████▉    | 300/505 [14:22<09:49,  2.88s/it]
#  60%|█████▉    | 301/505 [14:25<09:46,  2.87s/it]
#  60%|█████▉    | 302/505 [14:27<09:43,  2.87s/it]
#  60%|██████    | 303/505 [14:30<09:40,  2.87s/it]
#  60%|██████    | 304/505 [14:33<09:37,  2.87s/it]
#  60%|██████    | 305/505 [14:35<09:34,  2.87s/it]
#  61%|██████    | 306/505 [14:38<09:31,  2.87s/it]
#  61%|██████    | 307/505 [14:40<09:28,  2.87s/it]
#  79%|███████▉  | 401/505 [18:57<04:55,  2.84s/it]
#  80%|███████▉  | 402/505 [19:00<04:52,  2.84s/it]
#  80%|███████▉  | 403/505 [19:02<04:49,  2.84s/it]
#  80%|████████  | 404/505 [19:05<04:46,  2.83s/it]
#  80%|████████  | 405/505 [19:07<04:43,  2.83s/it]
#  80%|████████  | 406/505 [19:10<04:40,  2.83s/it]
#  81%|████████  | 407/505 [19:12<04:37,  2.83s/it]
#  81%|████████  | 408/505 [19:15<04:34,  2.83s/it]
#  81%|████████  | 409/505 [19:17<04:31,  2.83s/it]
#  81%|████████  | 410/505 [19:20<04:28,  2.83s/it]
#  81%|████████▏ | 411/505 [19:22<04:25,  2.83s/it]
#  82%|████████▏ | 412/505 [19:25<04:22,  2.83s/it]
#  82%|████████▏ | 413/505 [19:27<04:20,  2.83s/it]
#  82%|████████▏ | 414/505 [19:30<04:17,  2.83s/it]
#  82%|████████▏ | 415/505 [19:32<04:14,  2.83s/it]
#  82%|████████▏ | 416/505 [19:35<04:11,  2.82s/it]
#  83%|████████▎ | 417/505 [19:37<04:08,  2.82s/it]
#  83%|████████▎ | 418/505 [19:40<04:05,  2.82s/it]
#  83%|████████▎ | 419/505 [19:42<04:02,  2.82s/it]
#  83%|████████▎ | 420/505 [19:45<03:59,  2.82s/it]
#  83%|████████▎ | 421/505 [19:47<03:56,  2.82s/it]
#  84%|████████▎ | 422/505 [19:50<03:54,  2.82s/it]
#  84%|████████▍ | 423/505 [19:52<03:51,  2.82s/it]
#  84%|████████▍ | 424/505 [19:55<03:48,  2.82s/it]
#  84%|████████▍ | 425/505 [19:57<03:45,  2.82s/it]
#  84%|████████▍ | 426/505 [20:00<03:42,  2.82s/it]
#  85%|████████▍ | 427/505 [20:02<03:39,  2.82s/it]
#  85%|████████▍ | 428/505 [20:04<03:36,  2.82s/it]
#  85%|████████▍ | 429/505 [20:07<03:33,  2.81s/it]
#  85%|████████▌ | 430/505 [20:09<03:31,  2.81s/it]
#  85%|████████▌ | 431/505 [20:12<03:28,  2.81s/it]
#  86%|████████▌ | 432/505 [20:15<03:25,  2.81s/it]
#  86%|████████▌ | 433/505 [20:17<03:22,  2.81s/it]
#  86%|████████▌ | 434/505 [20:20<03:19,  2.81s/it]
#  86%|████████▌ | 435/505 [20:22<03:16,  2.81s/it]
#  86%|████████▋ | 436/505 [20:25<03:13,  2.81s/it]
#  87%|████████▋ | 437/505 [20:27<03:11,  2.81s/it]
#  87%|████████▋ | 438/505 [20:30<03:08,  2.81s/it]
#  87%|████████▋ | 439/505 [20:32<03:05,  2.81s/it]
#  87%|████████▋ | 440/505 [20:35<03:02,  2.81s/it]
#  87%|████████▋ | 441/505 [20:37<02:59,  2.81s/it]
#  88%|████████▊ | 442/505 [20:40<02:56,  2.81s/it]
#  88%|████████▊ | 443/505 [20:42<02:53,  2.81s/it]
#  88%|████████▊ | 444/505 [20:45<02:51,  2.80s/it]
#  88%|████████▊ | 445/505 [20:47<02:48,  2.80s/it]
#  88%|████████▊ | 446/505 [20:50<02:45,  2.80s/it]
#  89%|████████▊ | 447/505 [20:53<02:42,  2.80s/it]
#  89%|████████▊ | 448/505 [20:55<02:39,  2.80s/it]
#  89%|████████▉ | 449/505 [20:58<02:36,  2.80s/it]
#  89%|████████▉ | 450/505 [21:00<02:34,  2.80s/it]
#  89%|████████▉ | 451/505 [21:03<02:31,  2.80s/it]
#  90%|████████▉ | 452/505 [21:05<02:28,  2.80s/it]
#  90%|████████▉ | 453/505 [21:08<02:25,  2.80s/it]
#  90%|████████▉ | 454/505 [21:10<02:22,  2.80s/it]
#  90%|█████████ | 455/505 [21:13<02:19,  2.80s/it]
#  90%|█████████ | 456/505 [21:15<02:17,  2.80s/it]
#  90%|█████████ | 457/505 [21:18<02:14,  2.80s/it]
#  91%|█████████ | 458/505 [21:20<02:11,  2.80s/it]
#  91%|█████████ | 459/505 [21:23<02:08,  2.80s/it]
#  91%|█████████ | 460/505 [21:25<02:05,  2.80s/it]
#  91%|█████████▏| 461/505 [21:28<02:02,  2.79s/it]
#  91%|█████████▏| 462/505 [21:30<02:00,  2.79s/it]
#  92%|█████████▏| 463/505 [21:33<01:57,  2.79s/it]
#  92%|█████████▏| 464/505 [21:36<01:54,  2.79s/it]
#  92%|█████████▏| 465/505 [21:38<01:51,  2.79s/it]
#  92%|█████████▏| 466/505 [21:41<01:48,  2.79s/it]
#  92%|█████████▏| 467/505 [21:43<01:46,  2.79s/it]
#  93%|█████████▎| 468/505 [21:45<01:43,  2.79s/it]
#  93%|█████████▎| 469/505 [21:48<01:40,  2.79s/it]
#  93%|█████████▎| 470/505 [21:51<01:37,  2.79s/it]
#  93%|█████████▎| 471/505 [21:53<01:34,  2.79s/it]
#  93%|█████████▎| 472/505 [21:56<01:32,  2.79s/it]
#  94%|█████████▎| 473/505 [21:58<01:29,  2.79s/it]
#  94%|█████████▍| 474/505 [22:01<01:26,  2.79s/it]
#  94%|█████████▍| 475/505 [22:03<01:23,  2.79s/it]
#  94%|█████████▍| 476/505 [22:06<01:20,  2.79s/it]
#  94%|█████████▍| 477/505 [22:08<01:18,  2.79s/it]
#  95%|█████████▍| 478/505 [22:11<01:15,  2.79s/it]
#  95%|█████████▍| 479/505 [22:13<01:12,  2.78s/it]
#  95%|█████████▌| 480/505 [22:16<01:09,  2.78s/it]
#  95%|█████████▌| 481/505 [22:19<01:06,  2.78s/it]
#  95%|█████████▌| 482/505 [22:21<01:04,  2.78s/it]
#  96%|█████████▌| 483/505 [22:24<01:01,  2.78s/it]
#  96%|█████████▌| 484/505 [22:26<00:58,  2.78s/it]
#  96%|█████████▌| 485/505 [22:29<00:55,  2.78s/it]
#  96%|█████████▌| 486/505 [22:31<00:52,  2.78s/it]
#  96%|█████████▋| 487/505 [22:34<00:50,  2.78s/it]
#  97%|█████████▋| 488/505 [22:36<00:47,  2.78s/it]
#  97%|█████████▋| 489/505 [22:39<00:44,  2.78s/it]
#  97%|█████████▋| 490/505 [22:41<00:41,  2.78s/it]
#  97%|█████████▋| 491/505 [22:44<00:38,  2.78s/it]
#  97%|█████████▋| 492/505 [22:46<00:36,  2.78s/it]
#  98%|█████████▊| 493/505 [22:49<00:33,  2.78s/it]
#  98%|█████████▊| 494/505 [22:51<00:30,  2.78s/it]
#  98%|█████████▊| 495/505 [22:54<00:27,  2.78s/it]
#  98%|█████████▊| 496/505 [22:56<00:24,  2.78s/it]
#  98%|█████████▊| 497/505 [22:58<00:22,  2.77s/it]
#  99%|█████████▊| 498/505 [23:01<00:19,  2.77s/it]
#  99%|█████████▉| 499/505 [23:03<00:16,  2.77s/it]
#  99%|█████████▉| 500/505 [23:06<00:13,  2.77s/it]
#  99%|█████████▉| 501/505 [23:09<00:11,  2.77s/it]
#  99%|█████████▉| 502/505 [23:12<00:08,  2.77s/it]
# 100%|█████████▉| 503/505 [23:14<00:05,  2.77s/it]
# 100%|█████████▉| 504/505 [23:17<00:02,  2.77s/it]
# 100%|██████████| 505/505 [23:19<00:00,  2.77s/it]

# %%
print('ready')
# Out:
# ready

# %%
def showImSection(mylist):
    myim = io.imread(mylist[0])
    return myim[mylist[1]:mylist[2],mylist[3]:mylist[4]]

# %%
plt.imshow(showImSection(imCrops[3]))

# %%
# for i in tqdm.tqdm(range(L)):
#     imf[i,:] = ipca.transform(imageFeatureSections[i].reshape(1,-1))

# %%
# del imageFeatureSections

# %%
import pickle

# %%
search = {}
search['pca'] = ipca
search['features'] = imf
search['crops'] = imCrops

# %%
pickle.dump( search, open( "save.p", "wb" ) )

# %%
# pickle.dump( ipca, open( "hog-pca.p", "wb" ) )

# %%
imf_pca = ipca.transform(imf)

# %%
np.shape(imf_pca)

# %%
mydistances = distance.squareform(distance.pdist(imf_pca))

# %%
search_im = np.random.randint(low=0,high=1000)
# search_im = 533
plt.imshow(showImSection(imCrops[search_im]))
print(search_im)

# %%
plt.figure(figsize=(15,15))
idx = np.argsort(mydistances[search_im,:])
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.imshow( showImSection(imCrops[idx[i]]))
    plt.axis('off')
#     plt.title('Distance: ' + str(mydistances[search_im,idx[i]]))
    plt.title('Image: ' + str(imCrops[idx[i]][0].split('/')[-1]))

# %%
plt.hist(mydistances[search_im,:],100);

# %%
testIm = io.imread(allList[5])

# %%
# %matplotlib nbagg
fig, ax = plt.subplots(figsize=(10,10))
ax.imshow(testIm)
coords = []
def onclick(event):
    coords.append( [event.xdata, event.ydata])

cid = fig.canvas.mpl_connect('button_press_event', onclick)

# %%
xmin = int(coords[0][0])
ymin = int(coords[0][1])
xmax = int(coords[1][0])
ymax = int(coords[1][1])

# %%
[xmin, xmax, ymin, ymax]

# %%
# %matplotlib inline
plt.imshow(testIm[ymin:ymax,xmin:xmax,:])

# %%
queryIm = testIm[ymin:ymax,xmin:xmax,:]
queryIm = transform.resize(queryIm,(256,256,3))
queryF = feature.hog(queryIm,  pixels_per_cell=(16,16)  )

# %%
# querydistances = distance.cdist(imf,queryF.reshape(1,-1))

qf_pca = mypca.transform(queryF.reshape(1,-1))
querydistances = distance.cdist(imf_pca,qf_pca)

# %%
np.shape(imf)

# %%
plt.hist(querydistances,100);

# %%
plt.figure(figsize=(15,15))
idx = np.argsort(querydistances,axis=0)
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.imshow( showImSection(imCrops[  [idx[i][0]][0]      ]))
    plt.axis('off')
#     plt.title('distance = ' + str(querydistances[idx[i][0]]))
    plt.title('Crop number: ' + str(idx[i]))
