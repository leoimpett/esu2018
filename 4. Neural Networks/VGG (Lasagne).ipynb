# %% [markdown]
# # Art Style Transfer
#
# This notebook is an implementation of the algorithm described in "A Neural Algorithm of Artistic Style" (http://arxiv.org/abs/1508.06576) by Gatys, Ecker and Bethge. Additional details of their method are available at http://arxiv.org/abs/1505.07376 and https://bethgelab.org/deepneuralart/.
#
# An image is generated which combines the content of a photograph with the "style" of a painting. This is accomplished by jointly minimizing the squared difference between feature activation maps of the photo and generated image, and the squared difference of feature correlation between painting and generated image. A total variation penalty is also applied to reduce high frequency noise.

# %%
import lasagne
import numpy as np
import pickle
import skimage.transform
import scipy

import theano
import theano.tensor as T

from lasagne.utils import floatX

import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-3-7326e0e47779> in <module>()
# ----> 1 import lasagne
#       2 import numpy as np
#       3 import pickle
#       4 import skimage.transform
#       5 import scipy
#
# ~/anaconda3/envs/esu2018/lib/python3.5/site-packages/lasagne/__init__.py in <module>()
#      17 from . import nonlinearities
#      18 from . import init
# ---> 19 from . import layers
#      20 from . import objectives
#      21 from . import random
#
# ~/anaconda3/envs/esu2018/lib/python3.5/site-packages/lasagne/layers/__init__.py in <module>()
#       5 from .noise import *
#       6 from .conv import *
# ----> 7 from .pool import *
#       8 from .shape import *
#       9 from .merge import *
#
# ~/anaconda3/envs/esu2018/lib/python3.5/site-packages/lasagne/layers/pool.py in <module>()
#       4 from ..utils import as_tuple
#       5
# ----> 6 from theano.tensor.signal import downsample
#       7
#       8
#
# ImportError: cannot import name 'downsample'

# %%
# VGG-19, 19-layer model from the paper:
# "Very Deep Convolutional Networks for Large-Scale Image Recognition"
# Original source: https://gist.github.com/ksimonyan/3785162f95cd2d5fee77
# License: non-commercial use only

from lasagne.layers import InputLayer, DenseLayer, NonlinearityLayer
from lasagne.layers.dnn import Conv2DDNNLayer as ConvLayer
from lasagne.layers import Pool2DLayer as PoolLayer
from lasagne.nonlinearities import softmax

IMAGE_W = 600

# Note: tweaked to use average pooling instead of maxpooling
def build_model():
    net = {}
    net['input'] = InputLayer((1, 3, IMAGE_W, IMAGE_W))
  #    STYLE IMAGE (PAINTING):
    net['conv1_1'] = ConvLayer(net['input'], 64, 3, pad=1, flip_filters=False)
    net['conv1_2'] = ConvLayer(net['conv1_1'], 64, 3, pad=1, flip_filters=False)
    net['pool1'] = PoolLayer(net['conv1_2'], 2, mode='average_exc_pad')
    net['conv2_1'] = ConvLayer(net['pool1'], 128, 3, pad=1, flip_filters=False)
    net['conv2_2'] = ConvLayer(net['conv2_1'], 128, 3, pad=1, flip_filters=False)
    net['pool2'] = PoolLayer(net['conv2_2'], 2, mode='average_exc_pad')
    net['conv3_1'] = ConvLayer(net['pool2'], 256, 3, pad=1, flip_filters=False)
    net['conv3_2'] = ConvLayer(net['conv3_1'], 256, 3, pad=1, flip_filters=False)
    net['conv3_3'] = ConvLayer(net['conv3_2'], 256, 3, pad=1, flip_filters=False)
    net['conv3_4'] = ConvLayer(net['conv3_3'], 256, 3, pad=1, flip_filters=False)
    net['pool3'] = PoolLayer(net['conv3_4'], 2, mode='average_exc_pad')
    net['conv4_1'] = ConvLayer(net['pool3'], 512, 3, pad=1, flip_filters=False)
    net['conv4_2'] = ConvLayer(net['conv4_1'], 512, 3, pad=1, flip_filters=False)
    net['conv4_3'] = ConvLayer(net['conv4_2'], 512, 3, pad=1, flip_filters=False)
    # CONTENT IMAGE (PHOTOGRAPH):
    net['conv4_4'] = ConvLayer(net['conv4_3'], 512, 3, pad=1, flip_filters=False)
    net['pool4'] = PoolLayer(net['conv4_4'], 2, mode='average_exc_pad')
    net['conv5_1'] = ConvLayer(net['pool4'], 512, 3, pad=1, flip_filters=False)
    net['conv5_2'] = ConvLayer(net['conv5_1'], 512, 3, pad=1, flip_filters=False)
    net['conv5_3'] = ConvLayer(net['conv5_2'], 512, 3, pad=1, flip_filters=False)
    net['conv5_4'] = ConvLayer(net['conv5_3'], 512, 3, pad=1, flip_filters=False)
    net['pool5'] = PoolLayer(net['conv5_4'], 2, mode='average_exc_pad')

    return net

# %%
# Download the normalized pretrained weights from:
# https://s3.amazonaws.com/lasagne/recipes/pretrained/imagenet/vgg19_normalized.pkl
# (original source: https://bethgelab.org/deepneuralart/)

# !wget https://s3.amazonaws.com/lasagne/recipes/pretrained/imagenet/vgg19_normalized.pkl
# Out:
# --2018-03-22 17:00:32--  https://s3.amazonaws.com/lasagne/recipes/pretrained/imagenet/vgg19_normalized.pkl
# Resolving s3.amazonaws.com (s3.amazonaws.com)... 52.216.162.21
# Connecting to s3.amazonaws.com (s3.amazonaws.com)|52.216.162.21|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 80126892 (76M) [binary/octet-stream]
# Saving to: ‘vgg19_normalized.pkl.3’
#
# 100%[======================================>] 80,126,892  3.92MB/s   in 24s
#
# 2018-03-22 17:00:57 (3.13 MB/s) - ‘vgg19_normalized.pkl.3’ saved [80126892/80126892]

# %%
# build VGG net and load weights

net = build_model()

values = pickle.load(open('vgg19_normalized.pkl'))['param values']
lasagne.layers.set_all_param_values(net['pool5'], values)

# %%
MEAN_VALUES = np.array([104, 117, 123]).reshape((3,1,1))

def prep_image(im):
    if len(im.shape) == 2:
        im = im[:, :, np.newaxis]
        im = np.repeat(im, 3, axis=2)
    h, w, _ = im.shape
    if h < w:
        im = skimage.transform.resize(im, (IMAGE_W, w*IMAGE_W/h), preserve_range=True)
    else:
        im = skimage.transform.resize(im, (h*IMAGE_W/w, IMAGE_W), preserve_range=True)

    # Central crop
    h, w, _ = im.shape
    im = im[h//2-IMAGE_W//2:h//2+IMAGE_W//2, w//2-IMAGE_W//2:w//2+IMAGE_W//2]
    
    rawim = np.copy(im).astype('uint8')
    
    # Shuffle axes to c01
    im = np.swapaxes(np.swapaxes(im, 1, 2), 0, 1)
    
    # Convert RGB to BGR
    im = im[::-1, :, :]

    im = im - MEAN_VALUES
    return rawim, floatX(im[np.newaxis])

# %%
photo = plt.imread('Tuebingen_Neckarfront.jpg')
rawim, photo = prep_image(photo)
plt.imshow(rawim)

# %%
art = plt.imread('1920px-Van_Gogh_-_Starry_Night_-_Google_Art_Project.jpg')
rawim, art = prep_image(art)
plt.imshow(rawim)

# %%
def encoding_extract(P, layer):
    P = P[layer]
    return P



def gram_matrix(x):
    x = x.flatten(ndim=3)
    g = T.tensordot(x, x, axes=([2], [2]))
    return g


def content_loss(P, X, layer):
    p = P[layer]
    x = X[layer]
    
    loss = 1./2 * ((x - p)**2).sum()
    return loss


def style_loss(A, X, layer):
    a = A[layer]
    x = X[layer]
    
    A = gram_matrix(a)
    G = gram_matrix(x)
    
    N = a.shape[1]
    M = a.shape[2] * a.shape[3]
    
    loss = 1./(4 * N**2 * M**2) * ((G - A)**2).sum()
    return loss

def total_variation_loss(x):
    return (((x[:,:,:-1,:-1] - x[:,:,1:,:-1])**2 + (x[:,:,:-1,:-1] - x[:,:,:-1,1:])**2)**1.25).sum()

# %%
layers = ['conv4_2', 'conv1_1', 'conv2_1', 'conv3_1', 'conv4_1', 'conv5_1']
layers = {k: net[k] for k in layers}

# %%
# Precompute layer activations for photo and artwork
input_im_theano = T.tensor4()
outputs = lasagne.layers.get_output(layers.values(), input_im_theano)

photo_features = {k: theano.shared(output.eval({input_im_theano: photo}))
                  for k, output in zip(layers.keys(), outputs)}
art_features = {k: theano.shared(output.eval({input_im_theano: art}))
                for k, output in zip(layers.keys(), outputs)}
# Out:
# 1 #include <Python.h>
# 2 #include <iostream>
# 3 #include "theano_mod_helper.h"
# 4 #include "cuda_ndarray.cuh"
# 5 #include <math.h>
# 6 #include <numpy/arrayobject.h>
# 7 #include <numpy/arrayscalars.h>
# 8 #include "cudnn.h"
# 9 #include "cudnn_helper.h"
# 10 //////////////////////
# 11 ////  Support Code
# 12 //////////////////////
# 13
# 14
# 15 static cudnnHandle_t _handle = NULL;
# 16
# 17
# 18 static int
# 19 c_set_tensorNd(CudaNdarray *var, cudnnTensorDescriptor_t desc) {
# 20
# 21   int dim = CudaNdarray_NDIM(var);
# 22   int *strides = (int *)malloc(dim * sizeof(int));
# 23   int default_str = 1;
# 24   int return_value = 0;
# 25
# 26   if (strides != NULL) {
# 27     for (int i = dim-1; i >= 0; i--)
# 28     {
# 29       if (CudaNdarray_HOST_STRIDES(var)[i])
# 30         strides[i] = CudaNdarray_HOST_STRIDES(var)[i];
# 31       else
# 32         strides[i] = default_str;
# 33       default_str *= CudaNdarray_HOST_DIMS(var)[i];
# 34     }
# 35
# 36     cudnnStatus_t err = cudnnSetTensorNdDescriptor(desc, CUDNN_DATA_FLOAT, dim,
# 37                                                    CudaNdarray_HOST_DIMS(var),
# 38                                                    strides);
# 39
# 40
# 41     if (err != CUDNN_STATUS_SUCCESS) {
# 42       PyErr_Format(PyExc_RuntimeError,
# 43 		  "Could not set tensorNd descriptor: %s"
# 44 		  "dim=%d",
# 45 		  cudnnGetErrorString(err), dim);
# 46
# 47 	  return_value = -1;
# 48     }
# 49   } else {
# 50     PyErr_Format(PyExc_MemoryError,
# 51 		"Could not allocate memory for strides array of size %d.",
# 52 		dim);
# 53
# 54     return_value = -1;
# 55   }
# 56
# 57   free(strides);
# 58   return return_value;
# 59 }
# 60
# 61
# 62 static int
# 63 c_set_filterNd(CudaNdarray *var, cudnnFilterDescriptor_t desc) {
# 64   if (!CudaNdarray_is_c_contiguous(var)) {
# 65     PyErr_SetString(PyExc_ValueError,
# 66 		    "Only contiguous filters (kernels) are supported.");
# 67     return -1;
# 68   }
# 69   int dim = CudaNdarray_NDIM(var);
# 70   cudnnStatus_t err = cudnnSetFilterNdDescriptor_v4(desc,
# 71                                                     CUDNN_DATA_FLOAT,
# 72                                                     CUDNN_TENSOR_NCHW,
# 73                                                     dim,
# 74                                                     CudaNdarray_HOST_DIMS(var));
# 75   if (err != CUDNN_STATUS_SUCCESS) {
# 76     PyErr_Format(PyExc_RuntimeError,
# 77 		 "Could not set filter descriptor: %s."
# 78 		 " dims= %d",
# 79 		 cudnnGetErrorString(err), dim);
# 80     return -1;
# 81   }
# 82   return 0;
# 83 }
# 84
# 85
# 86
# 87     namespace {
# 88     struct __struct_compiled_op_b1b28962a86b2752ba91f7d762cc71c7 {
# 89         PyObject* __ERROR;
# 90
# 91         PyObject* storage_V3;
# 92 PyObject* storage_V5;
# 93 PyObject* storage_V7;
# 94 PyObject* storage_V9;
# 95 PyObject* storage_V11;
# 96 PyObject* storage_V13;
# 97 PyObject* storage_V1;
# 98
# 99 #define DTYPE_INPUT_0 npy_float32
# 100 #define TYPENUM_INPUT_0 11
# 101 #define ITEMSIZE_INPUT_0 4
# 102 #define DTYPE_INPUT_1 npy_float32
# 103 #define TYPENUM_INPUT_1 11
# 104 #define ITEMSIZE_INPUT_1 4
# 105 #define DTYPE_INPUT_2 npy_float32
# 106 #define TYPENUM_INPUT_2 11
# 107 #define ITEMSIZE_INPUT_2 4
# 108 #define DTYPE_INPUT_4 npy_float32
# 109 #define TYPENUM_INPUT_4 11
# 110 #define ITEMSIZE_INPUT_4 4
# 111 #define DTYPE_INPUT_5 npy_float32
# 112 #define TYPENUM_INPUT_5 11
# 113 #define ITEMSIZE_INPUT_5 4
# 114 #define DTYPE_OUTPUT_0 npy_float32
# 115 #define TYPENUM_OUTPUT_0 11
# 116 #define ITEMSIZE_OUTPUT_0 4
# 117 #define APPLY_SPECIFIC(str) str##_node_b1b28962a86b2752ba91f7d762cc71c7_0
# 118 #define CONV_ALGO CUDNN_CONVOLUTION_FWD_ALGO_IMPLICIT_PRECOMP_GEMM
# 119 #define CHOOSE_ALGO 0
# 120 #define CHOOSE_ALGO_ONCE 0
# 121 #define CHOOSE_ALGO_TIME 0
# 122 #define CONV_INPLACE 1
# 123
# 124 cudnnTensorDescriptor_t APPLY_SPECIFIC(input);
# 125 cudnnTensorDescriptor_t APPLY_SPECIFIC(output);
# 126 cudnnFilterDescriptor_t APPLY_SPECIFIC(kerns);
# 127
# 128 /* Keep track, from one execution to another, of the dimension of the data
# 129 and the algorithms, if any, that were selected according to these dimensions
# 130 and according to the amount of memory available at that time.
# 131
# 132 Note : Implementation selection for backward convolution only exists starting
# 133 at V3.
# 134 */
# 135 int APPLY_SPECIFIC(previous_input_shape)[5];
# 136 int APPLY_SPECIFIC(previous_kerns_shape)[5];
# 137 int APPLY_SPECIFIC(previous_output_shape)[5];
# 138 bool APPLY_SPECIFIC(previous_algo_set);
# 139 cudnnConvolutionFwdAlgo_t APPLY_SPECIFIC(previous_algo);
# 140 cudnnConvolutionBwdFilterAlgo_t APPLY_SPECIFIC(previous_bwd_f_algo);
# 141 cudnnConvolutionBwdDataAlgo_t APPLY_SPECIFIC(previous_bwd_d_algo);
# 142
# 143
# 144
# 145 int
# 146 APPLY_SPECIFIC(conv_fwd)(CudaNdarray *input, CudaNdarray *kerns,
# 147                          CudaNdarray *om, cudnnConvolutionDescriptor_t desc,
# 148                          float alpha, float beta, CudaNdarray **output) {
# 149
# 150   cudnnStatus_t err = CUDNN_STATUS_SUCCESS;
# 151   if (CudaNdarray_HOST_DIMS(input)[1] != CudaNdarray_HOST_DIMS(kerns)[1]) {
# 152     PyErr_SetString(PyExc_ValueError,
# 153                     "GpuDnnConv images and kernel must have the same stack size\n");
# 154     return 1;
# 155   }
# 156
# 157   if (c_set_tensorNd(input, APPLY_SPECIFIC(input)) == -1)
# 158     return 1;
# 159   if (c_set_filterNd(kerns, APPLY_SPECIFIC(kerns)) == -1)
# 160     return 1;
# 161
# 162   int nb_dim = CudaNdarray_NDIM(input);
# 163
# 164 #ifdef CONV_INPLACE
# 165   Py_XDECREF(*output);
# 166   *output = om;
# 167   Py_INCREF(*output);
# 168 #else
# 169   if (CudaNdarray_prep_output(output, nb_dim, CudaNdarray_HOST_DIMS(om)) != 0)
# 170     return 1;
# 171   if (beta != 0.0 && CudaNdarray_CopyFromCudaNdarray(*output, om))
# 172     return 1;
# 173 #endif
# 174
# 175    if (c_set_tensorNd(*output, APPLY_SPECIFIC(output)) == -1)
# 176      return 1;
# 177
# 178   {
# 179     size_t worksize;
# 180     void *workspace;
# 181     cudnnConvolutionFwdAlgo_t chosen_algo;
# 182
# 183
# 184     if (CHOOSE_ALGO)
# 185     {
# 186
# 187       // A new convolution implementation should be selected, based either on
# 188       // timing or heuristics if in one of the two following cases :
# 189       // - The implementation should only be chosen during the first execution
# 190       //   of an apply node and this is the first execution of the apply node.
# 191       // - The implementation should be chosen as often as necessary and the
# 192       //   shapes of the inputs differ from the last time an implementation
# 193       //   was chosen.
# 194       bool reuse_previous_algo;
# 195       if (CHOOSE_ALGO_ONCE)
# 196       {
# 197         // Only choose a new implementation of none has been chosen before.
# 198         reuse_previous_algo = APPLY_SPECIFIC(previous_algo_set);
# 199       }
# 200       else
# 201       {
# 202         // Reuse the previous implementation if the inputs and the kernels
# 203         // have the same shapes as they had when the previous implementation
# 204         // was selected
# 205         bool same_shapes = true;
# 206         for (int i = 0; (i < nb_dim) && same_shapes; i++)
# 207         {
# 208           same_shapes &= (CudaNdarray_HOST_DIMS(input)[i] ==
# 209                           APPLY_SPECIFIC(previous_input_shape)[i]);
# 210           same_shapes &= (CudaNdarray_HOST_DIMS(kerns)[i] ==
# 211                           APPLY_SPECIFIC(previous_kerns_shape)[i]);
# 212         }
# 213         reuse_previous_algo = same_shapes;
# 214       }
# 215
# 216       // If the previously choosen implementation can't be reused, select a
# 217       // new one based on the shapes of the current inputs
# 218       if (!reuse_previous_algo)
# 219       {
# 220
# 221         // Obtain a convolution algorithm appropriate for the input and kernel
# 222         // shapes. Either by choosing one according to heuristics or by making
# 223         // cuDNN time every implementation and choose the best one.
# 224         if (CHOOSE_ALGO_TIME)
# 225         {
# 226           // Time the different implementations to choose the best one
# 227           int requestedCount = 1;
# 228           int count;
# 229           cudnnConvolutionFwdAlgoPerf_t choosen_algo_perf;
# 230           err = cudnnFindConvolutionForwardAlgorithm(_handle,
# 231                                                      APPLY_SPECIFIC(input),
# 232                                                      APPLY_SPECIFIC(kerns),
# 233                                                      desc,
# 234                                                      APPLY_SPECIFIC(output),
# 235                                                      requestedCount,
# 236                                                      &count,
# 237                                                      &choosen_algo_perf);
# 238           if (err != CUDNN_STATUS_SUCCESS) {
# 239             PyErr_Format(PyExc_RuntimeError,
# 240                          "GpuDnnConv: error selecting convolution algo: %s",
# 241                          cudnnGetErrorString(err));
# 242             return 1;
# 243           }
# 244
# 245           chosen_algo = choosen_algo_perf.algo;
# 246         }
# 247         else
# 248         {
# 249           // The implementation should be chosen using heuristics based on the
# 250           // input shapes and the amount of memory available.
# 251
# 252           // Get the amount of available memory
# 253           size_t free = 0, total = 0;
# 254           cudaError_t err2 = cudaMemGetInfo(&free, &total);
# 255           if (err2 != cudaSuccess){
# 256             cudaGetLastError();
# 257             fprintf(stderr,
# 258                     "Error when trying to find the memory information"
# 259                     " on the GPU: %s\n", cudaGetErrorString(err2));
# 260             return 1;
# 261           }
# 262
# 263           // Use heuristics to choose the implementation
# 264           err = cudnnGetConvolutionForwardAlgorithm(_handle,
# 265                                                     APPLY_SPECIFIC(input),
# 266                                                     APPLY_SPECIFIC(kerns),
# 267                                                     desc,
# 268                                                     APPLY_SPECIFIC(output),
# 269                                                     CUDNN_CONVOLUTION_FWD_SPECIFY_WORKSPACE_LIMIT,
# 270                                                     free,
# 271                                                     &chosen_algo);
# 272
# 273           if (err != CUDNN_STATUS_SUCCESS) {
# 274             PyErr_Format(PyExc_RuntimeError,
# 275                          "GpuDnnConv: error selecting convolution algo: %s",
# 276                          cudnnGetErrorString(err));
# 277             return 1;
# 278           }
# 279         }
# 280
# 281         // Store the shapes of the inputs and kernels as well as the chosen
# 282         // algorithm for future use.
# 283         APPLY_SPECIFIC(previous_algo) = chosen_algo;
# 284         APPLY_SPECIFIC(previous_algo_set) = true;
# 285         for (int i = 0; i < nb_dim; i++)
# 286         {
# 287             APPLY_SPECIFIC(previous_input_shape)[i] =
# 288                                             CudaNdarray_HOST_DIMS(input)[i];
# 289             APPLY_SPECIFIC(previous_kerns_shape)[i] =
# 290                                             CudaNdarray_HOST_DIMS(kerns)[i];
# 291         }
# 292       }
# 293       else
# 294       {
# 295           // Reuse the previously chosen convolution implementation
# 296           chosen_algo = APPLY_SPECIFIC(previous_algo);
# 297       }
# 298     }
# 299     else
# 300     {
# 301       chosen_algo = CONV_ALGO;
# 302     }
# 303
# 304     // The FFT implementation (only in V3 and onward) does not support strides,
# 305     // 1x1 filters or inputs with a spatial dimension larger than 1024.
# 306     // The tiled-FFT implementation (only in V4 onward) does not support
# 307     // strides.
# 308     // If the chosen implementation is FFT or tiled-FFT, validate that it can
# 309     // be used on the current data and default on a safe implementation if it
# 310     // can't.
# 311     // Following code is 2d-specific, but it is fine as FFT and tiled-FFT are
# 312     // defined only for 2d-filters
# 313     if ((chosen_algo == CUDNN_CONVOLUTION_FWD_ALGO_FFT ||
# 314          chosen_algo == CUDNN_CONVOLUTION_FWD_ALGO_FFT_TILING) && nb_dim == 4)
# 315     {
# 316
# 317       // Extract the properties of the convolution descriptor
# 318       int nd;
# 319       int pad[2];
# 320       int stride[2];
# 321       int upscale[2];
# 322       cudnnConvolutionMode_t mode;
# 323       cudnnDataType_t data_type;
# 324       err = cudnnGetConvolutionNdDescriptor(desc, 2, &nd, pad, stride,
# 325                                             upscale, &mode, &data_type);
# 326
# 327       if (err != CUDNN_STATUS_SUCCESS) {
# 328         PyErr_Format(PyExc_RuntimeError,
# 329                      "GpuDnnConv: error getting convolution properties: %s",
# 330                      cudnnGetErrorString(err));
# 331         return 1;
# 332       }
# 333
# 334       // Extract the spatial size of the filters
# 335       int filter_h = CudaNdarray_HOST_DIMS(kerns)[2];
# 336       int filter_w = CudaNdarray_HOST_DIMS(kerns)[3];
# 337
# 338       // Extract the spatial size of the input
# 339       int input_h = CudaNdarray_HOST_DIMS(input)[2];
# 340       int input_w = CudaNdarray_HOST_DIMS(input)[3];
# 341
# 342       // Ensure that the selected implementation supports the requested
# 343       // convolution. Fall back to a safe implementation otherwise.
# 344       if (chosen_algo == CUDNN_CONVOLUTION_FWD_ALGO_FFT)
# 345       {
# 346         if (stride[0] != 1 || stride[1] != 1 || input_h > 1024 ||
# 347             input_w > 1024 || (filter_h == 1 && filter_w == 1))
# 348         {
# 349           chosen_algo = CUDNN_CONVOLUTION_FWD_ALGO_IMPLICIT_GEMM;
# 350         }
# 351       }
# 352       else
# 353       {
# 354         // chosen_algo == CUDNN_CONVOLUTION_FWD_ALGO_FFT_TILING
# 355         if (stride[0] != 1 || stride[1] != 1)
# 356         {
# 357           chosen_algo = CUDNN_CONVOLUTION_FWD_ALGO_IMPLICIT_GEMM;
# 358         }
# 359       }
# 360     }
# 361
# 362     err = cudnnGetConvolutionForwardWorkspaceSize(_handle,
# 363                                                   APPLY_SPECIFIC(input),
# 364                                                   APPLY_SPECIFIC(kerns),
# 365                                                   desc,
# 366                                                   APPLY_SPECIFIC(output),
# 367                                                   chosen_algo,
# 368                                                   &worksize);
# 369     if (err == CUDNN_STATUS_NOT_SUPPORTED) {
# 370       // Fallback to none algo if not supported
# 371       // TODO: Print a warning
# 372       chosen_algo = CUDNN_CONVOLUTION_FWD_ALGO_IMPLICIT_GEMM;
# 373
# 374       err = cudnnGetConvolutionForwardWorkspaceSize(_handle,
# 375                                                     APPLY_SPECIFIC(input),
# 376                                                     APPLY_SPECIFIC(kerns),
# 377                                                     desc,
# 378                                                     APPLY_SPECIFIC(output),
# 379                                                     chosen_algo,
# 380                                                     &worksize);
# 381     }
# 382     if (err != CUDNN_STATUS_SUCCESS) {
# 383       PyErr_Format(PyExc_RuntimeError,
# 384                    "GpuDnnConv: error getting worksize: %s",
# 385                    cudnnGetErrorString(err));
# 386       return 1;
# 387     }
# 388     workspace = get_work_mem(worksize);
# 389     if (workspace == NULL && worksize != 0)
# 390       return 1;
# 391
# 392     err = cudnnConvolutionForward(
# 393       _handle,
# 394       (void *)&alpha,
# 395       APPLY_SPECIFIC(input), CudaNdarray_DEV_DATA(input),
# 396       APPLY_SPECIFIC(kerns), CudaNdarray_DEV_DATA(kerns),
# 397       desc,
# 398       chosen_algo,
# 399       workspace, worksize,
# 400       (void *)&beta,
# 401       APPLY_SPECIFIC(output), CudaNdarray_DEV_DATA(*output));
# 402   }
# 403   if (err != CUDNN_STATUS_SUCCESS) {
# 404     PyErr_Format(PyExc_RuntimeError, "GpuDnnConv: error doing operation: %s",
# 405 		 cudnnGetErrorString(err));
# 406     return 1;
# 407   }
# 408   return 0;
# 409 }
# 410
# 411 #undef DTYPE_INPUT_0
# 412 #undef TYPENUM_INPUT_0
# 413 #undef ITEMSIZE_INPUT_0
# 414 #undef DTYPE_INPUT_1
# 415 #undef TYPENUM_INPUT_1
# 416 #undef ITEMSIZE_INPUT_1
# 417 #undef DTYPE_INPUT_2
# 418 #undef TYPENUM_INPUT_2
# 419 #undef ITEMSIZE_INPUT_2
# 420 #undef DTYPE_INPUT_4
# 421 #undef TYPENUM_INPUT_4
# 422 #undef ITEMSIZE_INPUT_4
# 423 #undef DTYPE_INPUT_5
# 424 #undef TYPENUM_INPUT_5
# 425 #undef ITEMSIZE_INPUT_5
# 426 #undef DTYPE_OUTPUT_0
# 427 #undef TYPENUM_OUTPUT_0
# 428 #undef ITEMSIZE_OUTPUT_0
# 429 #undef APPLY_SPECIFIC
# 430 #undef CONV_ALGO
# 431 #undef CHOOSE_ALGO
# 432 #undef CHOOSE_ALGO_ONCE
# 433 #undef CHOOSE_ALGO_TIME
# 434 #undef CONV_INPLACE
# 435
# 436         __struct_compiled_op_b1b28962a86b2752ba91f7d762cc71c7() {
# 437             // This is only somewhat safe because we:
# 438             //  1) Are not a virtual class
# 439             //  2) Do not use any virtual classes in the members
# 440             //  3) Deal with mostly POD and pointers
# 441
# 442             // If this changes, we would have to revise this, but for
# 443             // now I am tired of chasing segfaults because
# 444             // initialization code had an error and some pointer has
# 445             // a junk value.
# 446             memset(this, 0, sizeof(*this));
# 447         }
# 448         ~__struct_compiled_op_b1b28962a86b2752ba91f7d762cc71c7(void) {
# 449             cleanup();
# 450         }
# 451
# 452         int init(PyObject* __ERROR, PyObject* storage_V3, PyObject* storage_V5, PyObject* storage_V7, PyObject* storage_V9, PyObject* storage_V11, PyObject* storage_V13, PyObject* storage_V1) {
# 453             Py_XINCREF(storage_V3);
# 454 Py_XINCREF(storage_V5);
# 455 Py_XINCREF(storage_V7);
# 456 Py_XINCREF(storage_V9);
# 457 Py_XINCREF(storage_V11);
# 458 Py_XINCREF(storage_V13);
# 459 Py_XINCREF(storage_V1);
# 460             this->storage_V3 = storage_V3;
# 461 this->storage_V5 = storage_V5;
# 462 this->storage_V7 = storage_V7;
# 463 this->storage_V9 = storage_V9;
# 464 this->storage_V11 = storage_V11;
# 465 this->storage_V13 = storage_V13;
# 466 this->storage_V1 = storage_V1;
# 467
# 468
# 469
# 470
# 471
# 472
# 473
# 474
# 475
# 476 #define DTYPE_INPUT_0 npy_float32
# 477 #define TYPENUM_INPUT_0 11
# 478 #define ITEMSIZE_INPUT_0 4
# 479 #define DTYPE_INPUT_1 npy_float32
# 480 #define TYPENUM_INPUT_1 11
# 481 #define ITEMSIZE_INPUT_1 4
# 482 #define DTYPE_INPUT_2 npy_float32
# 483 #define TYPENUM_INPUT_2 11
# 484 #define ITEMSIZE_INPUT_2 4
# 485 #define DTYPE_INPUT_4 npy_float32
# 486 #define TYPENUM_INPUT_4 11
# 487 #define ITEMSIZE_INPUT_4 4
# 488 #define DTYPE_INPUT_5 npy_float32
# 489 #define TYPENUM_INPUT_5 11
# 490 #define ITEMSIZE_INPUT_5 4
# 491 #define DTYPE_OUTPUT_0 npy_float32
# 492 #define TYPENUM_OUTPUT_0 11
# 493 #define ITEMSIZE_OUTPUT_0 4
# 494 #define APPLY_SPECIFIC(str) str##_node_b1b28962a86b2752ba91f7d762cc71c7_0
# 495 #define CONV_ALGO CUDNN_CONVOLUTION_FWD_ALGO_IMPLICIT_PRECOMP_GEMM
# 496 #define CHOOSE_ALGO 0
# 497 #define CHOOSE_ALGO_ONCE 0
# 498 #define CHOOSE_ALGO_TIME 0
# 499 #define CONV_INPLACE 1
# 500 #define FAIL { \
# 501         if (!PyErr_Occurred()) { \
# 502             PyErr_SetString(PyExc_RuntimeError, \
# 503                 "Unexpected error in an Op's C code. " \
# 504                 "No Python exception was set."); \
# 505             } \
# 506         return 15; \
# 507 }
# 508
# 509
# 510 cudnnStatus_t APPLY_SPECIFIC(err);
# 511 APPLY_SPECIFIC(input) = NULL;
# 512 APPLY_SPECIFIC(output) = NULL;
# 513 APPLY_SPECIFIC(kerns) = NULL;
# 514 if ((APPLY_SPECIFIC(err) = cudnnCreateTensorDescriptor(&APPLY_SPECIFIC(input))) != CUDNN_STATUS_SUCCESS) {
# 515   PyErr_Format(PyExc_MemoryError, "could not allocate tensor descriptor "
# 516 	       "(inp): %s", cudnnGetErrorString(APPLY_SPECIFIC(err)));
# 517   FAIL;
# 518 }
# 519 if ((APPLY_SPECIFIC(err) = cudnnCreateTensorDescriptor(&APPLY_SPECIFIC(output))) != CUDNN_STATUS_SUCCESS) {
# 520   PyErr_Format(PyExc_MemoryError, "could not allocate tensor descriptor "
# 521                "(out): %s", cudnnGetErrorString(APPLY_SPECIFIC(err)));
# 522   FAIL;
# 523 }
# 524 if ((APPLY_SPECIFIC(err) = cudnnCreateFilterDescriptor(&APPLY_SPECIFIC(kerns))) != CUDNN_STATUS_SUCCESS) {
# 525   PyErr_Format(PyExc_MemoryError, "could not allocate filter descriptor: %s",
# 526 	       cudnnGetErrorString(APPLY_SPECIFIC(err)));
# 527   FAIL;
# 528 }
# 529
# 530 for (int i = 0; i < 5; i++)
# 531 {
# 532   APPLY_SPECIFIC(previous_input_shape)[i] = 0;
# 533   APPLY_SPECIFIC(previous_kerns_shape)[i] = 0;
# 534   APPLY_SPECIFIC(previous_output_shape)[i] = 0;
# 535 }
# 536
# 537 APPLY_SPECIFIC(previous_algo_set) = false;
# 538
# 539 // Select default implementations for the case where the convolution
# 540 // implementations should be selected based on the size of the data.
# 541 APPLY_SPECIFIC(previous_algo) = CUDNN_CONVOLUTION_FWD_ALGO_IMPLICIT_PRECOMP_GEMM;
# 542 APPLY_SPECIFIC(previous_bwd_f_algo) = CUDNN_CONVOLUTION_BWD_FILTER_ALGO_0;
# 543 APPLY_SPECIFIC(previous_bwd_d_algo) = CUDNN_CONVOLUTION_BWD_DATA_ALGO_0;
# 544
# 545
# 546 #undef FAIL
# 547 #undef DTYPE_INPUT_0
# 548 #undef TYPENUM_INPUT_0
# 549 #undef ITEMSIZE_INPUT_0
# 550 #undef DTYPE_INPUT_1
# 551 #undef TYPENUM_INPUT_1
# 552 #undef ITEMSIZE_INPUT_1
# 553 #undef DTYPE_INPUT_2
# 554 #undef TYPENUM_INPUT_2
# 555 #undef ITEMSIZE_INPUT_2
# 556 #undef DTYPE_INPUT_4
# 557 #undef TYPENUM_INPUT_4
# 558 #undef ITEMSIZE_INPUT_4
# 559 #undef DTYPE_INPUT_5
# 560 #undef TYPENUM_INPUT_5
# 561 #undef ITEMSIZE_INPUT_5
# 562 #undef DTYPE_OUTPUT_0
# 563 #undef TYPENUM_OUTPUT_0
# 564 #undef ITEMSIZE_OUTPUT_0
# 565 #undef APPLY_SPECIFIC
# 566 #undef CONV_ALGO
# 567 #undef CHOOSE_ALGO
# 568 #undef CHOOSE_ALGO_ONCE
# 569 #undef CHOOSE_ALGO_TIME
# 570 #undef CONV_INPLACE
# 571             this->__ERROR = __ERROR;
# 572             return 0;
# 573         }
# 574         void cleanup(void) {
# 575             __label_1:
# 576
# 577 double __DUMMY_1;
# 578 __label_3:
# 579
# 580 double __DUMMY_3;
# 581 __label_5:
# 582
# 583 double __DUMMY_5;
# 584 __label_7:
# 585
# 586 double __DUMMY_7;
# 587 __label_9:
# 588
# 589 double __DUMMY_9;
# 590 __label_11:
# 591
# 592 double __DUMMY_11;
# 593 __label_13:
# 594
# 595 double __DUMMY_13;
# 596 __label_16:
# 597
# 598 #define DTYPE_INPUT_0 npy_float32
# 599 #define TYPENUM_INPUT_0 11
# 600 #define ITEMSIZE_INPUT_0 4
# 601 #define DTYPE_INPUT_1 npy_float32
# 602 #define TYPENUM_INPUT_1 11
# 603 #define ITEMSIZE_INPUT_1 4
# 604 #define DTYPE_INPUT_2 npy_float32
# 605 #define TYPENUM_INPUT_2 11
# 606 #define ITEMSIZE_INPUT_2 4
# 607 #define DTYPE_INPUT_4 npy_float32
# 608 #define TYPENUM_INPUT_4 11
# 609 #define ITEMSIZE_INPUT_4 4
# 610 #define DTYPE_INPUT_5 npy_float32
# 611 #define TYPENUM_INPUT_5 11
# 612 #define ITEMSIZE_INPUT_5 4
# 613 #define DTYPE_OUTPUT_0 npy_float32
# 614 #define TYPENUM_OUTPUT_0 11
# 615 #define ITEMSIZE_OUTPUT_0 4
# 616 #define APPLY_SPECIFIC(str) str##_node_b1b28962a86b2752ba91f7d762cc71c7_0
# 617 #define CONV_ALGO CUDNN_CONVOLUTION_FWD_ALGO_IMPLICIT_PRECOMP_GEMM
# 618 #define CHOOSE_ALGO 0
# 619 #define CHOOSE_ALGO_ONCE 0
# 620 #define CHOOSE_ALGO_TIME 0
# 621 #define CONV_INPLACE 1
# 622
# 623
# 624 if (APPLY_SPECIFIC(input) != NULL)
# 625   cudnnDestroyTensorDescriptor(APPLY_SPECIFIC(input));
# 626 if (APPLY_SPECIFIC(output) != NULL)
# 627   cudnnDestroyTensorDescriptor(APPLY_SPECIFIC(output));
# 628 if (APPLY_SPECIFIC(kerns) != NULL)
# 629   cudnnDestroyFilterDescriptor(APPLY_SPECIFIC(kerns));
# 630
# 631 #undef DTYPE_INPUT_0
# 632 #undef TYPENUM_INPUT_0
# 633 #undef ITEMSIZE_INPUT_0
# 634 #undef DTYPE_INPUT_1
# 635 #undef TYPENUM_INPUT_1
# 636 #undef ITEMSIZE_INPUT_1
# 637 #undef DTYPE_INPUT_2
# 638 #undef TYPENUM_INPUT_2
# 639 #undef ITEMSIZE_INPUT_2
# 640 #undef DTYPE_INPUT_4
# 641 #undef TYPENUM_INPUT_4
# 642 #undef ITEMSIZE_INPUT_4
# 643 #undef DTYPE_INPUT_5
# 644 #undef TYPENUM_INPUT_5
# 645 #undef ITEMSIZE_INPUT_5
# 646 #undef DTYPE_OUTPUT_0
# 647 #undef TYPENUM_OUTPUT_0
# 648 #undef ITEMSIZE_OUTPUT_0
# 649 #undef APPLY_SPECIFIC
# 650 #undef CONV_ALGO
# 651 #undef CHOOSE_ALGO
# 652 #undef CHOOSE_ALGO_ONCE
# 653 #undef CHOOSE_ALGO_TIME
# 654 #undef CONV_INPLACE
# 655 double __DUMMY_16;
# 656
# 657             Py_XDECREF(this->storage_V3);
# 658 Py_XDECREF(this->storage_V5);
# 659 Py_XDECREF(this->storage_V7);
# 660 Py_XDECREF(this->storage_V9);
# 661 Py_XDECREF(this->storage_V11);
# 662 Py_XDECREF(this->storage_V13);
# 663 Py_XDECREF(this->storage_V1);
# 664         }
# 665         int run(void) {
# 666             int __failure = 0;
# 667
# 668     PyObject* py_V1;
# 669      CudaNdarray * V1;
# 670     PyObject* py_V3;
# 671      CudaNdarray * V3;
# 672     PyObject* py_V5;
# 673      CudaNdarray * V5;
# 674     PyObject* py_V7;
# 675      CudaNdarray * V7;
# 676     PyObject* py_V9;
# 677
# 678         cudnnConvolutionDescriptor_t V9;
# 679
# 680     PyObject* py_V11;
# 681
# 682                 typedef npy_float32 V11_dtype; // Deprecated use dtype_V11 instead.
# 683                 typedef npy_float32 dtype_V11;
# 684
# 685         npy_float32 V11;
# 686
# 687     PyObject* py_V13;
# 688
# 689                 typedef npy_float32 V13_dtype; // Deprecated use dtype_V13 instead.
# 690                 typedef npy_float32 dtype_V13;
# 691
# 692         npy_float32 V13;
# 693
# 694 {
# 695
# 696     py_V1 = PyList_GET_ITEM(storage_V1, 0);
# 697     {Py_XINCREF(py_V1);}
# 698
# 699         if (py_V1 == Py_None)
# 700         {
# 701             V1 = NULL;
# 702         }
# 703         else
# 704         {
# 705
# 706         assert(py_V1->ob_refcnt >= 2); // There should be at least one ref from the container object,
# 707         // and one ref from the local scope.
# 708
# 709         if (CudaNdarray_Check(py_V1))
# 710         {
# 711             //fprintf(stderr, "c_extract CNDA object w refcnt %p %i\n", py_V1, (py_V1->ob_refcnt));
# 712             V1 = (CudaNdarray*)py_V1;
# 713             //std::cerr << "c_extract " << V1 << '\n';
# 714
# 715
# 716                 if (V1->nd != 4)
# 717                 {
# 718                     PyErr_Format(PyExc_RuntimeError,
# 719                                  "c_extract: Some CudaNdarray has rank %i, it was supposed to have rank 4",
# 720                                  V1->nd);
# 721                     V1 = NULL;
# 722                     {
# 723         __failure = 2;
# 724         if (!PyErr_Occurred()) {
# 725             PyErr_SetString(PyExc_RuntimeError,
# 726                 "Unexpected error in an Op's C code. "
# 727                 "No Python exception was set.");
# 728             }
# 729         goto __label_2;};
# 730                 }
# 731                 //std::cerr << "c_extract " << V1 << " nd check passed\n";
# 732
# 733
# 734                 assert(V1);
# 735                 Py_INCREF(py_V1);
# 736             }
# 737             else if (py_V1 == Py_None)
# 738             {
# 739                 PyErr_SetString(PyExc_TypeError,
# 740                                 "expected a CudaNdarray, not None");
# 741                 V1 = NULL;
# 742                 {
# 743         __failure = 2;
# 744         if (!PyErr_Occurred()) {
# 745             PyErr_SetString(PyExc_RuntimeError,
# 746                 "Unexpected error in an Op's C code. "
# 747                 "No Python exception was set.");
# 748             }
# 749         goto __label_2;};
# 750             }
# 751             else
# 752             {
# 753                 //fprintf(stderr, "FAILING c_extract CNDA object w refcnt %p %i\n", py_V1, (py_V1->ob_refcnt));
# 754                 PyErr_SetString(PyExc_TypeError, "Argument not a CudaNdarray");
# 755                 V1 = NULL;
# 756                 {
# 757         __failure = 2;
# 758         if (!PyErr_Occurred()) {
# 759             PyErr_SetString(PyExc_RuntimeError,
# 760                 "Unexpected error in an Op's C code. "
# 761                 "No Python exception was set.");
# 762             }
# 763         goto __label_2;};
# 764             }
# 765             //std::cerr << "c_extract done " << V1 << '\n';
# 766
# 767
# 768         }
# 769
# 770 {
# 771
# 772     py_V3 = PyList_GET_ITEM(storage_V3, 0);
# 773     {Py_XINCREF(py_V3);}
# 774
# 775         assert(py_V3->ob_refcnt >= 2); // There should be at least one ref from the container object,
# 776         // and one ref from the local scope.
# 777
# 778         if (CudaNdarray_Check(py_V3))
# 779         {
# 780             //fprintf(stderr, "c_extract CNDA object w refcnt %p %i\n", py_V3, (py_V3->ob_refcnt));
# 781             V3 = (CudaNdarray*)py_V3;
# 782             //std::cerr << "c_extract " << V3 << '\n';
# 783
# 784
# 785                 if (V3->nd != 4)
# 786                 {
# 787                     PyErr_Format(PyExc_RuntimeError,
# 788                                  "c_extract: Some CudaNdarray has rank %i, it was supposed to have rank 4",
# 789                                  V3->nd);
# 790                     V3 = NULL;
# 791                     {
# 792         __failure = 4;
# 793         if (!PyErr_Occurred()) {
# 794             PyErr_SetString(PyExc_RuntimeError,
# 795                 "Unexpected error in an Op's C code. "
# 796                 "No Python exception was set.");
# 797             }
# 798         goto __label_4;};
# 799                 }
# 800                 //std::cerr << "c_extract " << V3 << " nd check passed\n";
# 801
# 802
# 803                 assert(V3);
# 804                 Py_INCREF(py_V3);
# 805             }
# 806             else if (py_V3 == Py_None)
# 807             {
# 808                 PyErr_SetString(PyExc_TypeError,
# 809                                 "expected a CudaNdarray, not None");
# 810                 V3 = NULL;
# 811                 {
# 812         __failure = 4;
# 813         if (!PyErr_Occurred()) {
# 814             PyErr_SetString(PyExc_RuntimeError,
# 815                 "Unexpected error in an Op's C code. "
# 816                 "No Python exception was set.");
# 817             }
# 818         goto __label_4;};
# 819             }
# 820             else
# 821             {
# 822                 //fprintf(stderr, "FAILING c_extract CNDA object w refcnt %p %i\n", py_V3, (py_V3->ob_refcnt));
# 823                 PyErr_SetString(PyExc_TypeError, "Argument not a CudaNdarray");
# 824                 V3 = NULL;
# 825                 {
# 826         __failure = 4;
# 827         if (!PyErr_Occurred()) {
# 828             PyErr_SetString(PyExc_RuntimeError,
# 829                 "Unexpected error in an Op's C code. "
# 830                 "No Python exception was set.");
# 831             }
# 832         goto __label_4;};
# 833             }
# 834             //std::cerr << "c_extract done " << V3 << '\n';
# 835
# 836
# 837 {
# 838
# 839     py_V5 = PyList_GET_ITEM(storage_V5, 0);
# 840     {Py_XINCREF(py_V5);}
# 841
# 842         assert(py_V5->ob_refcnt >= 2); // There should be at least one ref from the container object,
# 843         // and one ref from the local scope.
# 844
# 845         if (CudaNdarray_Check(py_V5))
# 846         {
# 847             //fprintf(stderr, "c_extract CNDA object w refcnt %p %i\n", py_V5, (py_V5->ob_refcnt));
# 848             V5 = (CudaNdarray*)py_V5;
# 849             //std::cerr << "c_extract " << V5 << '\n';
# 850
# 851
# 852                 if (V5->nd != 4)
# 853                 {
# 854                     PyErr_Format(PyExc_RuntimeError,
# 855                                  "c_extract: Some CudaNdarray has rank %i, it was supposed to have rank 4",
# 856                                  V5->nd);
# 857                     V5 = NULL;
# 858                     {
# 859         __failure = 6;
# 860         if (!PyErr_Occurred()) {
# 861             PyErr_SetString(PyExc_RuntimeError,
# 862                 "Unexpected error in an Op's C code. "
# 863                 "No Python exception was set.");
# 864             }
# 865         goto __label_6;};
# 866                 }
# 867                 //std::cerr << "c_extract " << V5 << " nd check passed\n";
# 868
# 869
# 870                 assert(V5);
# 871                 Py_INCREF(py_V5);
# 872             }
# 873             else if (py_V5 == Py_None)
# 874             {
# 875                 PyErr_SetString(PyExc_TypeError,
# 876                                 "expected a CudaNdarray, not None");
# 877                 V5 = NULL;
# 878                 {
# 879         __failure = 6;
# 880         if (!PyErr_Occurred()) {
# 881             PyErr_SetString(PyExc_RuntimeError,
# 882                 "Unexpected error in an Op's C code. "
# 883                 "No Python exception was set.");
# 884             }
# 885         goto __label_6;};
# 886             }
# 887             else
# 888             {
# 889                 //fprintf(stderr, "FAILING c_extract CNDA object w refcnt %p %i\n", py_V5, (py_V5->ob_refcnt));
# 890                 PyErr_SetString(PyExc_TypeError, "Argument not a CudaNdarray");
# 891                 V5 = NULL;
# 892                 {
# 893         __failure = 6;
# 894         if (!PyErr_Occurred()) {
# 895             PyErr_SetString(PyExc_RuntimeError,
# 896                 "Unexpected error in an Op's C code. "
# 897                 "No Python exception was set.");
# 898             }
# 899         goto __label_6;};
# 900             }
# 901             //std::cerr << "c_extract done " << V5 << '\n';
# 902
# 903
# 904 {
# 905
# 906     py_V7 = PyList_GET_ITEM(storage_V7, 0);
# 907     {Py_XINCREF(py_V7);}
# 908
# 909         assert(py_V7->ob_refcnt >= 2); // There should be at least one ref from the container object,
# 910         // and one ref from the local scope.
# 911
# 912         if (CudaNdarray_Check(py_V7))
# 913         {
# 914             //fprintf(stderr, "c_extract CNDA object w refcnt %p %i\n", py_V7, (py_V7->ob_refcnt));
# 915             V7 = (CudaNdarray*)py_V7;
# 916             //std::cerr << "c_extract " << V7 << '\n';
# 917
# 918
# 919                 if (V7->nd != 4)
# 920                 {
# 921                     PyErr_Format(PyExc_RuntimeError,
# 922                                  "c_extract: Some CudaNdarray has rank %i, it was supposed to have rank 4",
# 923                                  V7->nd);
# 924                     V7 = NULL;
# 925                     {
# 926         __failure = 8;
# 927         if (!PyErr_Occurred()) {
# 928             PyErr_SetString(PyExc_RuntimeError,
# 929                 "Unexpected error in an Op's C code. "
# 930                 "No Python exception was set.");
# 931             }
# 932         goto __label_8;};
# 933                 }
# 934                 //std::cerr << "c_extract " << V7 << " nd check passed\n";
# 935
# 936
# 937                 assert(V7);
# 938                 Py_INCREF(py_V7);
# 939             }
# 940             else if (py_V7 == Py_None)
# 941             {
# 942                 PyErr_SetString(PyExc_TypeError,
# 943                                 "expected a CudaNdarray, not None");
# 944                 V7 = NULL;
# 945                 {
# 946         __failure = 8;
# 947         if (!PyErr_Occurred()) {
# 948             PyErr_SetString(PyExc_RuntimeError,
# 949                 "Unexpected error in an Op's C code. "
# 950                 "No Python exception was set.");
# 951             }
# 952         goto __label_8;};
# 953             }
# 954             else
# 955             {
# 956                 //fprintf(stderr, "FAILING c_extract CNDA object w refcnt %p %i\n", py_V7, (py_V7->ob_refcnt));
# 957                 PyErr_SetString(PyExc_TypeError, "Argument not a CudaNdarray");
# 958                 V7 = NULL;
# 959                 {
# 960         __failure = 8;
# 961         if (!PyErr_Occurred()) {
# 962             PyErr_SetString(PyExc_RuntimeError,
# 963                 "Unexpected error in an Op's C code. "
# 964                 "No Python exception was set.");
# 965             }
# 966         goto __label_8;};
# 967             }
# 968             //std::cerr << "c_extract done " << V7 << '\n';
# 969
# 970
# 971 {
# 972
# 973     py_V9 = PyList_GET_ITEM(storage_V9, 0);
# 974     {Py_XINCREF(py_V9);}
# 975
# 976   V9 = (cudnnConvolutionDescriptor_t)PyCObject_AsVoidPtr(py_V9);
# 977
# 978 {
# 979
# 980     py_V11 = PyList_GET_ITEM(storage_V11, 0);
# 981     {Py_XINCREF(py_V11);}
# 982
# 983             if (!PyObject_TypeCheck(py_V11, &PyFloat32ArrType_Type))
# 984             {
# 985                 PyErr_Format(PyExc_ValueError,
# 986                     "Scalar check failed (npy_float32)");
# 987                 {
# 988         __failure = 12;
# 989         if (!PyErr_Occurred()) {
# 990             PyErr_SetString(PyExc_RuntimeError,
# 991                 "Unexpected error in an Op's C code. "
# 992                 "No Python exception was set.");
# 993             }
# 994         goto __label_12;}
# 995             }
# 996
# 997         PyArray_ScalarAsCtype(py_V11, &V11);
# 998
# 999 {
# 1000
# 1001     py_V13 = PyList_GET_ITEM(storage_V13, 0);
# 1002     {Py_XINCREF(py_V13);}
# 1003
# 1004             if (!PyObject_TypeCheck(py_V13, &PyFloat32ArrType_Type))
# 1005             {
# 1006                 PyErr_Format(PyExc_ValueError,
# 1007                     "Scalar check failed (npy_float32)");
# 1008                 {
# 1009         __failure = 14;
# 1010         if (!PyErr_Occurred()) {
# 1011             PyErr_SetString(PyExc_RuntimeError,
# 1012                 "Unexpected error in an Op's C code. "
# 1013                 "No Python exception was set.");
# 1014             }
# 1015         goto __label_14;}
# 1016             }
# 1017
# 1018         PyArray_ScalarAsCtype(py_V13, &V13);
# 1019
# 1020 {
# 1021 // Op class GpuDnnConv
# 1022
# 1023                 #define APPLY_SPECIFIC(str) str##_node_b1b28962a86b2752ba91f7d762cc71c7_0
# 1024 #define CONV_ALGO CUDNN_CONVOLUTION_FWD_ALGO_IMPLICIT_PRECOMP_GEMM
# 1025 #define CHOOSE_ALGO 0
# 1026 #define CHOOSE_ALGO_ONCE 0
# 1027 #define CHOOSE_ALGO_TIME 0
# 1028 #define CONV_INPLACE 1
# 1029                 {
# 1030                   if (APPLY_SPECIFIC(conv_fwd)(V3, V5, V7, V9, V11, V13, &V1) != 0) {
# 1031                     {
# 1032         __failure = 15;
# 1033         if (!PyErr_Occurred()) {
# 1034             PyErr_SetString(PyExc_RuntimeError,
# 1035                 "Unexpected error in an Op's C code. "
# 1036                 "No Python exception was set.");
# 1037             }
# 1038         goto __label_15;}
# 1039                   }
# 1040                 }
# 1041                 #undef APPLY_SPECIFIC
# 1042 #undef CONV_ALGO
# 1043 #undef CHOOSE_ALGO
# 1044 #undef CHOOSE_ALGO_ONCE
# 1045 #undef CHOOSE_ALGO_TIME
# 1046 #undef CONV_INPLACE
# 1047                 __label_15:
# 1048
# 1049 double __DUMMY_15;
# 1050
# 1051 }
# 1052 __label_14:
# 1053
# 1054     {Py_XDECREF(py_V13);}
# 1055
# 1056 double __DUMMY_14;
# 1057
# 1058 }
# 1059 __label_12:
# 1060
# 1061     {Py_XDECREF(py_V11);}
# 1062
# 1063 double __DUMMY_12;
# 1064
# 1065 }
# 1066 __label_10:
# 1067
# 1068     {Py_XDECREF(py_V9);}
# 1069
# 1070 double __DUMMY_10;
# 1071
# 1072 }
# 1073 __label_8:
# 1074
# 1075         //std::cerr << "cleanup " << py_V7 << " " << V7 << "\n";
# 1076         //fprintf(stderr, "c_cleanup CNDA py_object w refcnt %p %i\n", py_V7, (py_V7->ob_refcnt));
# 1077         if (V7)
# 1078         {
# 1079             //fprintf(stderr, "c_cleanup CNDA cn_object w refcnt %p %i\n", V7, (V7->ob_refcnt));
# 1080             Py_XDECREF(V7);
# 1081         }
# 1082         //std::cerr << "cleanup done" << py_V7 << "\n";
# 1083
# 1084     {Py_XDECREF(py_V7);}
# 1085
# 1086 double __DUMMY_8;
# 1087
# 1088 }
# 1089 __label_6:
# 1090
# 1091         //std::cerr << "cleanup " << py_V5 << " " << V5 << "\n";
# 1092         //fprintf(stderr, "c_cleanup CNDA py_object w refcnt %p %i\n", py_V5, (py_V5->ob_refcnt));
# 1093         if (V5)
# 1094         {
# 1095             //fprintf(stderr, "c_cleanup CNDA cn_object w refcnt %p %i\n", V5, (V5->ob_refcnt));
# 1096             Py_XDECREF(V5);
# 1097         }
# 1098         //std::cerr << "cleanup done" << py_V5 << "\n";
# 1099
# 1100     {Py_XDECREF(py_V5);}
# 1101
# 1102 double __DUMMY_6;
# 1103
# 1104 }
# 1105 __label_4:
# 1106
# 1107         //std::cerr << "cleanup " << py_V3 << " " << V3 << "\n";
# 1108         //fprintf(stderr, "c_cleanup CNDA py_object w refcnt %p %i\n", py_V3, (py_V3->ob_refcnt));
# 1109         if (V3)
# 1110         {
# 1111             //fprintf(stderr, "c_cleanup CNDA cn_object w refcnt %p %i\n", V3, (V3->ob_refcnt));
# 1112             Py_XDECREF(V3);
# 1113         }
# 1114         //std::cerr << "cleanup done" << py_V3 << "\n";
# 1115
# 1116     {Py_XDECREF(py_V3);}
# 1117
# 1118 double __DUMMY_4;
# 1119
# 1120 }
# 1121 __label_2:
# 1122
# 1123     if (!__failure) {
# 1124
# 1125         //std::cerr << "sync\n";
# 1126         if (NULL == V1) {
# 1127             // failure: sync None to storage
# 1128             Py_XDECREF(py_V1);
# 1129             py_V1 = Py_None;
# 1130             Py_INCREF(py_V1);
# 1131         }
# 1132         else
# 1133         {
# 1134             if (py_V1 != (PyObject*)V1)
# 1135             {
# 1136                 Py_XDECREF(py_V1);
# 1137                 py_V1 = (PyObject*)V1;
# 1138                 Py_INCREF(py_V1);
# 1139             }
# 1140             assert(py_V1->ob_refcnt);
# 1141         }
# 1142
# 1143       PyObject* old = PyList_GET_ITEM(storage_V1, 0);
# 1144       {Py_XINCREF(py_V1);}
# 1145       PyList_SET_ITEM(storage_V1, 0, py_V1);
# 1146       {Py_XDECREF(old);}
# 1147     }
# 1148
# 1149         //std::cerr << "cleanup " << py_V1 << " " << V1 << "\n";
# 1150         //fprintf(stderr, "c_cleanup CNDA py_object w refcnt %p %i\n", py_V1, (py_V1->ob_refcnt));
# 1151         if (V1)
# 1152         {
# 1153             //fprintf(stderr, "c_cleanup CNDA cn_object w refcnt %p %i\n", V1, (V1->ob_refcnt));
# 1154             Py_XDECREF(V1);
# 1155         }
# 1156         //std::cerr << "cleanup done" << py_V1 << "\n";
# 1157
# 1158     {Py_XDECREF(py_V1);}
# 1159
# 1160 double __DUMMY_2;
# 1161
# 1162 }
# 1163
# 1164
# 1165         if (__failure) {
# 1166             // When there is a failure, this code puts the exception
# 1167             // in __ERROR.
# 1168             PyObject* err_type = NULL;
# 1169             PyObject* err_msg = NULL;
# 1170             PyObject* err_traceback = NULL;
# 1171             PyErr_Fetch(&err_type, &err_msg, &err_traceback);
# 1172             if (!err_type) {err_type = Py_None;Py_INCREF(Py_None);}
# 1173             if (!err_msg) {err_msg = Py_None; Py_INCREF(Py_None);}
# 1174             if (!err_traceback) {err_traceback = Py_None; Py_INCREF(Py_None);}
# 1175             PyObject* old_err_type = PyList_GET_ITEM(__ERROR, 0);
# 1176             PyObject* old_err_msg = PyList_GET_ITEM(__ERROR, 1);
# 1177             PyObject* old_err_traceback = PyList_GET_ITEM(__ERROR, 2);
# 1178             PyList_SET_ITEM(__ERROR, 0, err_type);
# 1179             PyList_SET_ITEM(__ERROR, 1, err_msg);
# 1180             PyList_SET_ITEM(__ERROR, 2, err_traceback);
# 1181             {Py_XDECREF(old_err_type);}
# 1182             {Py_XDECREF(old_err_msg);}
# 1183             {Py_XDECREF(old_err_traceback);}
# 1184         }
# 1185         // The failure code is returned to index what code block failed.
# 1186         return __failure;
# 1187
# 1188         }
# 1189     };
# 1190     }
# 1191
# 1192
# 1193         static int __struct_compiled_op_b1b28962a86b2752ba91f7d762cc71c7_executor(__struct_compiled_op_b1b28962a86b2752ba91f7d762cc71c7* self) {
# 1194             return self->run();
# 1195         }
# 1196
# 1197         static void __struct_compiled_op_b1b28962a86b2752ba91f7d762cc71c7_destructor(void* executor, void* self) {
# 1198             delete ((__struct_compiled_op_b1b28962a86b2752ba91f7d762cc71c7*)self);
# 1199         }
# 1200
# 1201 //////////////////////
# 1202 ////  Functions
# 1203 //////////////////////
# 1204 static PyObject * instantiate(PyObject * self, PyObject *argtuple) {
# 1205   assert(PyTuple_Check(argtuple));
# 1206   if (8 != PyTuple_Size(argtuple)){
# 1207      PyErr_Format(PyExc_TypeError, "Wrong number of arguments, expected 8, got %i", (int)PyTuple_Size(argtuple));
# 1208      return NULL;
# 1209   }
# 1210   __struct_compiled_op_b1b28962a86b2752ba91f7d762cc71c7* struct_ptr = new __struct_compiled_op_b1b28962a86b2752ba91f7d762cc71c7();
# 1211   if (struct_ptr->init( PyTuple_GET_ITEM(argtuple, 0),PyTuple_GET_ITEM(argtuple, 1),PyTuple_GET_ITEM(argtuple, 2),PyTuple_GET_ITEM(argtuple, 3),PyTuple_GET_ITEM(argtuple, 4),PyTuple_GET_ITEM(argtuple, 5),PyTuple_GET_ITEM(argtuple, 6),PyTuple_GET_ITEM(argtuple, 7) ) != 0) {
# 1212     delete struct_ptr;
# 1213     return NULL;
# 1214   }
# 1215   PyObject* thunk = PyCObject_FromVoidPtrAndDesc((void*)(&__struct_compiled_op_b1b28962a86b2752ba91f7d762cc71c7_executor), struct_ptr, __struct_compiled_op_b1b28962a86b2752ba91f7d762cc71c7_destructor);
# 1216   return thunk; }
# 1217
# 1218 //////////////////////
# 1219 ////  Module init
# 1220 //////////////////////
# 1221 static PyMethodDef MyMethods[] = {
# 1222 	{"instantiate", instantiate, METH_VARARGS, "undocumented"} ,
# 1223 	{NULL, NULL, 0, NULL}
# 1224 };
# 1225 PyMODINIT_FUNC initb1b28962a86b2752ba91f7d762cc71c7(void){
# 1226    import_array();
# 1227
# 1228
# 1229 {
# 1230   cudnnStatus_t err;
# 1231   if ((err = cudnnCreate(&_handle)) != CUDNN_STATUS_SUCCESS) {
# 1232     PyErr_Format(PyExc_RuntimeError, "could not create cuDNN handle: %s",
# 1233 		 cudnnGetErrorString(err));
# 1234 #if PY_MAJOR_VERSION >= 3
# 1235     return NULL;
# 1236 #else
# 1237     return;
# 1238 #endif
# 1239   }
# 1240 }
# 1241
# 1242    (void) Py_InitModule("b1b28962a86b2752ba91f7d762cc71c7", MyMethods);
# 1243 }
# 1244
# ===============================
# In file included from /home/impett/anaconda3/envs/py27/include/python2.7/Python.h:8:0,
#                  from mod.cu:1:
# /home/impett/anaconda3/envs/py27/include/python2.7/pyconfig.h:1190:0: warning: "_POSIX_C_SOURCE" redefined [enabled by default]
#  #define _POSIX_C_SOURCE 200112L
#  ^
# In file included from /usr/local/cuda/include/host_config.h:173:0,
#                  from /usr/local/cuda/include/cuda_runtime.h:78,
#                  from <command-line>:0:
# /usr/include/features.h:230:0: note: this is the location of the previous definition
#  # define _POSIX_C_SOURCE 200809L
#  ^
# In file included from /home/impett/anaconda3/envs/py27/include/python2.7/Python.h:8:0,
#                  from mod.cu:1:
# /home/impett/anaconda3/envs/py27/include/python2.7/pyconfig.h:1212:0: warning: "_XOPEN_SOURCE" redefined [enabled by default]
#  #define _XOPEN_SOURCE 600
#  ^
# In file included from /usr/local/cuda/include/host_config.h:173:0,
#                  from /usr/local/cuda/include/cuda_runtime.h:78,
#                  from <command-line>:0:
# /usr/include/features.h:162:0: note: this is the location of the previous definition
#  # define _XOPEN_SOURCE 700
#  ^
# mod.cu(70): error: identifier "cudnnSetFilterNdDescriptor_v4" is undefined
# 1 error detected in the compilation of "/tmp/tmpxft_000145e5_00000000-9_mod.cpp1.ii".
# ['nvcc', '-shared', '-O3', '-Xlinker', '-rpath,/usr/local/cuda/lib64', '-arch=sm_52', '-m64', '-Xcompiler', '-fno-math-errno,-Wno-unused-label,-Wno-unused-variable,-Wno-write-strings,-DCUDA_NDARRAY_CUH=c72d035fdf91890f3b36710688069b2e,-DNPY_NO_DEPRECATED_API=NPY_1_7_API_VERSION,-fPIC,-fvisibility=hidden', '-Xlinker', '-rpath,/home/impett/.theano/compiledir_Linux-3.13--generic-x86_64-with-debian-jessie-sid-x86_64-2.7.13-64/cuda_ndarray', '-I/home/impett/.theano/compiledir_Linux-3.13--generic-x86_64-with-debian-jessie-sid-x86_64-2.7.13-64/cuda_ndarray', '-I/usr/local/cuda/include', '-I/home/impett/anaconda3/envs/py27/lib/python2.7/site-packages/theano/sandbox/cuda', '-I/home/impett/anaconda3/envs/py27/lib/python2.7/site-packages/numpy/core/include', '-I/home/impett/anaconda3/envs/py27/include/python2.7', '-I/home/impett/anaconda3/envs/py27/lib/python2.7/site-packages/theano/gof', '-o', '/home/impett/.theano/compiledir_Linux-3.13--generic-x86_64-with-debian-jessie-sid-x86_64-2.7.13-64/tmpcmpnN5/b1b28962a86b2752ba91f7d762cc71c7.so', 'mod.cu', '-L/home/impett/.theano/compiledir_Linux-3.13--generic-x86_64-with-debian-jessie-sid-x86_64-2.7.13-64/cuda_ndarray', '-L/home/impett/anaconda3/envs/py27/lib', '-lcudart', '-lcublas', '-lcuda_ndarray', '-lcudnn', '-lpython2.7']
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-10-3d673e8afc79> in <module>()
#       4
#       5 photo_features = {k: theano.shared(output.eval({input_im_theano: photo}))
# ----> 6                   for k, output in zip(layers.keys(), outputs)}
#       7 art_features = {k: theano.shared(output.eval({input_im_theano: art}))
#       8                 for k, output in zip(layers.keys(), outputs)}
#
# <ipython-input-10-3d673e8afc79> in <dictcomp>((k, output))
#       4
#       5 photo_features = {k: theano.shared(output.eval({input_im_theano: photo}))
# ----> 6                   for k, output in zip(layers.keys(), outputs)}
#       7 art_features = {k: theano.shared(output.eval({input_im_theano: art}))
#       8                 for k, output in zip(layers.keys(), outputs)}
#
# /home/impett/anaconda3/envs/py27/lib/python2.7/site-packages/theano/gof/graph.pyc in eval(self, inputs_to_values)
#     518         inputs = tuple(sorted(inputs_to_values.keys(), key=id))
#     519         if inputs not in self._fn_cache:
# --> 520             self._fn_cache[inputs] = theano.function(inputs, self)
#     521         args = [inputs_to_values[param] for param in inputs]
#     522
#
# /home/impett/anaconda3/envs/py27/lib/python2.7/site-packages/theano/compile/function.pyc in function(inputs, outputs, mode, updates, givens, no_default_updates, accept_inplace, name, rebuild_strict, allow_input_downcast, profile, on_unused_input)
#     318                    on_unused_input=on_unused_input,
#     319                    profile=profile,
# --> 320                    output_keys=output_keys)
#     321     # We need to add the flag check_aliased inputs if we have any mutable or
#     322     # borrowed used defined inputs
#
# /home/impett/anaconda3/envs/py27/lib/python2.7/site-packages/theano/compile/pfunc.pyc in pfunc(params, outputs, mode, updates, givens, no_default_updates, accept_inplace, name, rebuild_strict, allow_input_downcast, profile, on_unused_input, output_keys)
#     477                          accept_inplace=accept_inplace, name=name,
#     478                          profile=profile, on_unused_input=on_unused_input,
# --> 479                          output_keys=output_keys)
#     480
#     481
#
# /home/impett/anaconda3/envs/py27/lib/python2.7/site-packages/theano/compile/function_module.pyc in orig_function(inputs, outputs, mode, accept_inplace, name, profile, on_unused_input, output_keys)
#    1775                    on_unused_input=on_unused_input,
#    1776                    output_keys=output_keys).create(
# -> 1777             defaults)
#    1778
#    1779     t2 = time.time()
#
# /home/impett/anaconda3/envs/py27/lib/python2.7/site-packages/theano/compile/function_module.pyc in create(self, input_storage, trustme, storage_map)
#    1639             theano.config.traceback.limit = 0
#    1640             _fn, _i, _o = self.linker.make_thunk(
# -> 1641                 input_storage=input_storage_lists, storage_map=storage_map)
#    1642         finally:
#    1643             theano.config.traceback.limit = limit_orig
#
# /home/impett/anaconda3/envs/py27/lib/python2.7/site-packages/theano/gof/link.pyc in make_thunk(self, input_storage, output_storage, storage_map)
#     688         return self.make_all(input_storage=input_storage,
#     689                              output_storage=output_storage,
# --> 690                              storage_map=storage_map)[:3]
#     691
#     692     def make_all(self, input_storage, output_storage):
#
# /home/impett/anaconda3/envs/py27/lib/python2.7/site-packages/theano/gof/vm.pyc in make_all(self, profiler, input_storage, output_storage, storage_map)
#    1001                                                  storage_map,
#    1002                                                  compute_map,
# -> 1003                                                  no_recycling))
#    1004                 if not hasattr(thunks[-1], 'lazy'):
#    1005                     # We don't want all ops maker to think about lazy Ops.
#
# /home/impett/anaconda3/envs/py27/lib/python2.7/site-packages/theano/sandbox/cuda/__init__.pyc in make_thunk(self, node, storage_map, compute_map, no_recycling)
#     254                 enable_cuda=False)
#     255         return super(GpuOp, self).make_thunk(node, storage_map,
# --> 256                                              compute_map, no_recycling)
#     257
#     258 theano.compile.debugmode.default_make_thunk.append(
#
# /home/impett/anaconda3/envs/py27/lib/python2.7/site-packages/theano/gof/op.pyc in make_thunk(self, node, storage_map, compute_map, no_recycling)
#     968             try:
#     969                 return self.make_c_thunk(node, storage_map, compute_map,
# --> 970                                          no_recycling)
#     971             except (NotImplementedError, utils.MethodNotDefined):
#     972                 logger.debug('Falling back on perform')
#
# /home/impett/anaconda3/envs/py27/lib/python2.7/site-packages/theano/gof/op.pyc in make_c_thunk(self, node, storage_map, compute_map, no_recycling)
#     877         logger.debug('Trying CLinker.make_thunk')
#     878         outputs = cl.make_thunk(input_storage=node_input_storage,
# --> 879                                 output_storage=node_output_storage)
#     880         fill_storage, node_input_filters, node_output_filters = outputs
#     881
#
# /home/impett/anaconda3/envs/py27/lib/python2.7/site-packages/theano/gof/cc.pyc in make_thunk(self, input_storage, output_storage, storage_map, keep_lock)
#    1198         cthunk, in_storage, out_storage, error_storage = self.__compile__(
#    1199             input_storage, output_storage, storage_map,
# -> 1200             keep_lock=keep_lock)
#    1201
#    1202         res = _CThunk(cthunk, init_tasks, tasks, error_storage)
#
# /home/impett/anaconda3/envs/py27/lib/python2.7/site-packages/theano/gof/cc.pyc in __compile__(self, input_storage, output_storage, storage_map, keep_lock)
#    1141                                     output_storage,
#    1142                                     storage_map,
# -> 1143                                     keep_lock=keep_lock)
#    1144         return (thunk,
#    1145                 [link.Container(input, storage) for input, storage in
#
# /home/impett/anaconda3/envs/py27/lib/python2.7/site-packages/theano/gof/cc.pyc in cthunk_factory(self, error_storage, in_storage, out_storage, storage_map, keep_lock)
#    1593         else:
#    1594             module = get_module_cache().module_from_key(
# -> 1595                 key=key, lnk=self, keep_lock=keep_lock)
#    1596
#    1597         vars = self.inputs + self.outputs + self.orphans
#
# /home/impett/anaconda3/envs/py27/lib/python2.7/site-packages/theano/gof/cmodule.pyc in module_from_key(self, key, lnk, keep_lock)
#    1140             try:
#    1141                 location = dlimport_workdir(self.dirname)
# -> 1142                 module = lnk.compile_cmodule(location)
#    1143                 name = module.__file__
#    1144                 assert name.startswith(location)
#
# /home/impett/anaconda3/envs/py27/lib/python2.7/site-packages/theano/gof/cc.pyc in compile_cmodule(self, location)
#    1504                 lib_dirs=self.lib_dirs(),
#    1505                 libs=libs,
# -> 1506                 preargs=preargs)
#    1507         except Exception as e:
#    1508             e.args += (str(self.fgraph),)
#
# /home/impett/anaconda3/envs/py27/lib/python2.7/site-packages/theano/sandbox/cuda/nvcc_compiler.pyc in compile_str(module_name, src_code, location, include_dirs, lib_dirs, libs, preargs, rpaths, py_module, hide_symbols)
#     397             print(cmd)
#     398             raise Exception('nvcc return status', p.returncode,
# --> 399                             'for cmd', ' '.join(cmd))
#     400         elif config.cmodule.compilation_warning and nvcc_stdout:
#     401             print(nvcc_stdout)
#
# Exception: ('The following error happened while compiling the node', GpuDnnConv{algo='small', inplace=True}(GpuContiguous.0, GpuContiguous.0, GpuAllocEmpty.0, GpuDnnConvDesc{border_mode=(1, 1), subsample=(1, 1), conv_mode='cross', precision='float32'}.0, Constant{1.0}, Constant{0.0}), '\n', 'nvcc return status', 2, 'for cmd', 'nvcc -shared -O3 -Xlinker -rpath,/usr/local/cuda/lib64 -arch=sm_52 -m64 -Xcompiler -fno-math-errno,-Wno-unused-label,-Wno-unused-variable,-Wno-write-strings,-DCUDA_NDARRAY_CUH=c72d035fdf91890f3b36710688069b2e,-DNPY_NO_DEPRECATED_API=NPY_1_7_API_VERSION,-fPIC,-fvisibility=hidden -Xlinker -rpath,/home/impett/.theano/compiledir_Linux-3.13--generic-x86_64-with-debian-jessie-sid-x86_64-2.7.13-64/cuda_ndarray -I/home/impett/.theano/compiledir_Linux-3.13--generic-x86_64-with-debian-jessie-sid-x86_64-2.7.13-64/cuda_ndarray -I/usr/local/cuda/include -I/home/impett/anaconda3/envs/py27/lib/python2.7/site-packages/theano/sandbox/cuda -I/home/impett/anaconda3/envs/py27/lib/python2.7/site-packages/numpy/core/include -I/home/impett/anaconda3/envs/py27/include/python2.7 -I/home/impett/anaconda3/envs/py27/lib/python2.7/site-packages/theano/gof -o /home/impett/.theano/compiledir_Linux-3.13--generic-x86_64-with-debian-jessie-sid-x86_64-2.7.13-64/tmpcmpnN5/b1b28962a86b2752ba91f7d762cc71c7.so mod.cu -L/home/impett/.theano/compiledir_Linux-3.13--generic-x86_64-with-debian-jessie-sid-x86_64-2.7.13-64/cuda_ndarray -L/home/impett/anaconda3/envs/py27/lib -lcudart -lcublas -lcuda_ndarray -lcudnn -lpython2.7', "[GpuDnnConv{algo='small', inplace=True}(<CudaNdarrayType(float32, 4D)>, <CudaNdarrayType(float32, 4D)>, <CudaNdarrayType(float32, 4D)>, <CDataType{cudnnConvolutionDescriptor_t}>, Constant{1.0}, Constant{0.0})]")

# %%
# Get expressions for layer activations for generated image
generated_image = theano.shared(floatX(np.random.uniform(-128, 128, (1, 3, IMAGE_W, IMAGE_W))))

gen_features = lasagne.layers.get_output(layers.values(), generated_image)
gen_features = {k: v for k, v in zip(layers.keys(), gen_features)}

# %%
# Define loss function
losses = []

# content loss
losses.append(0.001 * content_loss(photo_features, gen_features, 'conv4_2'))

# style loss
losses.append(0.2e6 * style_loss(art_features, gen_features, 'conv1_1'))
losses.append(0.2e6 * style_loss(art_features, gen_features, 'conv2_1'))
losses.append(0.2e6 * style_loss(art_features, gen_features, 'conv3_1'))
losses.append(0.2e6 * style_loss(art_features, gen_features, 'conv4_1'))
losses.append(0.2e6 * style_loss(art_features, gen_features, 'conv5_1'))

# total variation penalty
losses.append(0.1e-7 * total_variation_loss(generated_image))

total_loss = sum(losses)

# %%
grad = T.grad(total_loss, generated_image)

# %%
# Theano functions to evaluate loss and gradient
f_loss = theano.function([], total_loss)
f_grad = theano.function([], grad)

# Helper functions to interface with scipy.optimize
def eval_loss(x0):
    x0 = floatX(x0.reshape((1, 3, IMAGE_W, IMAGE_W)))
    generated_image.set_value(x0)
    return f_loss().astype('float64')

def eval_grad(x0):
    x0 = floatX(x0.reshape((1, 3, IMAGE_W, IMAGE_W)))
    generated_image.set_value(x0)
    return np.array(f_grad()).flatten().astype('float64')

# %%
photo_features['conv5_1']

# %%
# Initialize with a noise image
generated_image.set_value(floatX(np.random.uniform(-128, 128, (1, 3, IMAGE_W, IMAGE_W))))

x0 = generated_image.get_value().astype('float64')
xs = []
xs.append(x0)

# Optimize, saving the result periodically
for i in range(8):
    print(i)
    scipy.optimize.fmin_l_bfgs_b(eval_loss, x0.flatten(), fprime=eval_grad, maxfun=40)
    x0 = generated_image.get_value().astype('float64')
    xs.append(x0)

# %%
def deprocess(x):
    x = np.copy(x[0])
    x += MEAN_VALUES

    x = x[::-1]
    x = np.swapaxes(np.swapaxes(x, 0, 1), 1, 2)
    
    x = np.clip(x, 0, 255).astype('uint8')
    return x

# %%
plt.figure(figsize=(12,12))
for i in range(9):
    plt.subplot(3, 3, i+1)
    plt.gca().xaxis.set_visible(False)    
    plt.gca().yaxis.set_visible(False)    
    plt.imshow(deprocess(xs[i]))
plt.tight_layout()

# %%
plt.figure(figsize=(8,8))
plt.imshow(deprocess(xs[-1]), interpolation='nearest')

# %%
print('Arte!')

# %%
min(5,20)
# Out:
# 5
