# %%
# maths library for matrix manipulation
import numpy as np

# matplotlib is a library for plotting things inside Python
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
# This is a library for reading and writing image files

from skimage import io

# %%
# a library for finding files


import glob

# %%
JPGList = glob.glob('../ImageData/all cards/*.jpg')


PNGList = glob.glob('../ImageData/all cards/*.png')

# %%
len(JPGList)
# Out:
# 202

# %%
allList = JPGList + PNGList

# %%
# allList is the list of all image file names

len(allList)
# Out:
# 287

# %%
allList[130]
# Out:
# '../ImageData/all cards/48.jpg'

# %%
io.imread(    allList[130]     )
# Out:
# array([[[187, 180, 152],
#         [189, 181, 162],
#         [142, 130, 118],
#         ...,
#         [138, 129, 124],
#         [100,  95,  92],
#         [ 27,  27,  29]],
#
#        [[191, 181, 156],
#         [156, 145, 127],
#         [149, 137, 125],
#         ...,
#         [142, 131, 127],
#         [ 55,  50,  47],
#         [ 20,  20,  22]],
#
#        [[166, 154, 130],
#         [159, 146, 130],
#         [160, 146, 135],
#         ...,
#         [150, 139, 133],
#         [ 71,  66,  63],
#         [ 44,  44,  46]],
#
#        ...,
#
#        [[187, 171, 155],
#         [214, 198, 182],
#         [210, 197, 180],
#         ...,
#         [105,  97,  86],
#         [116, 109,  99],
#         [184, 177, 169]],
#
#        [[201, 185, 169],
#         [193, 177, 161],
#         [205, 190, 171],
#         ...,
#         [ 96,  87,  78],
#         [141, 134, 126],
#         [193, 186, 180]],
#
#        [[204, 187, 171],
#         [193, 178, 159],
#         [206, 191, 172],
#         ...,
#         [113, 103, 101],
#         [173, 165, 163],
#         [198, 189, 190]]], dtype=uint8)

# %%
plt.imshow(     io.imread(    allList[130]     )     )

# %%
Im = io.imread( allList[130] )

# %%
from skimage import feature

# %%
from skimage import transform

# %%
Imr = transform.resize(Im,(256,256))
# Out:
# /home/impett/anaconda3/envs/esu2018/lib/python3.5/site-packages/skimage/transform/_warps.py:105: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/impett/anaconda3/envs/esu2018/lib/python3.5/site-packages/skimage/transform/_warps.py:110: UserWarning: Anti-aliasing will be enabled by default in skimage 0.15 to avoid aliasing artifacts when down-sampling images.
#   warn("Anti-aliasing will be enabled by default in skimage 0.15 to "

# %%
F = feature.hog(Imr,  pixels_per_cell=(16,16)  )
# Out:
# /home/impett/anaconda3/envs/esu2018/lib/python3.5/site-packages/skimage/feature/_hog.py:150: skimage_deprecation: Default value of `block_norm`==`L1` is deprecated and will be changed to `L2-Hys` in v0.15. To supress this message specify explicitly the normalization method.
#   skimage_deprecation)

# %%
import tqdm

# %%
from nst_utils import *
import tensorflow as tf

# %%
# Reset the graph
tf.reset_default_graph()

#GPU configs (Optional)
config = tf.ConfigProto()
config.gpu_options.allow_growth=True
config.gpu_options.per_process_gpu_memory_fraction = 0.25

#start the session
sess = tf.InteractiveSession(config=config)

# %%
content_image = plt.imread('tubingen.jpg')
content_image = transform.resize(content_image,(640,640,3))
print(content_image.shape)
plt.imshow(content_image)

content_image = reshape_and_normalize_image(content_image)
# Out:
# /home/impett/anaconda3/envs/esu2018/lib/python3.5/site-packages/skimage/transform/_warps.py:105: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/impett/anaconda3/envs/esu2018/lib/python3.5/site-packages/skimage/transform/_warps.py:110: UserWarning: Anti-aliasing will be enabled by default in skimage 0.15 to avoid aliasing artifacts when down-sampling images.
#   warn("Anti-aliasing will be enabled by default in skimage 0.15 to "
# (640, 640, 3)

# %%
model = load_vgg_model("../Networks/imagenet-vgg-verydeep-19.mat")

# %%
content_image = reshape_and_normalize_image(content_image)

sess.run(model['input'].assign(content_image))

out = model['conv5_4']

NNFeature = sess.run(out)

# %%
np.shape(NNFeature.flatten())

# %%
def GetNNFeature(input_image):
    input_image = transform.resize(input_image,(640,640,3))
    content_image = reshape_and_normalize_image(input_image)
    sess.run(model['input'].assign(content_image))
    out = model['conv5_4']
    NNFeature = sess.run(out)
    return NNFeature.flatten()

# %%
imageFeatures = []
for fileName in tqdm.tqdm(allList):
    im = io.imread(fileName)
    F = GetNNFeature(im)
    imageFeatures.append(F)
# Out:
#   0%|          | 0/287 [00:00<?, ?it/s]/home/impett/anaconda3/envs/esu2018/lib/python3.5/site-packages/skimage/transform/_warps.py:105: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/impett/anaconda3/envs/esu2018/lib/python3.5/site-packages/skimage/transform/_warps.py:110: UserWarning: Anti-aliasing will be enabled by default in skimage 0.15 to avoid aliasing artifacts when down-sampling images.
#   warn("Anti-aliasing will be enabled by default in skimage 0.15 to "
#   2%|▏         | 6/287 [00:54<42:25,  9.06s/it]

# %%
-

# %%
imf = np.asarray(imageFeatures)

# %%
plt.scatter(xy[:,0],xy[:,1])

# %%
np.shape(xy)
# Out:
# (287, 2)

# %%
xy[:,1]
# Out:
# array([-6.00316405e-01, -7.94239402e-01, -4.72682667e+00,  3.15416312e+00,
#         4.94370270e+00, -1.09557115e-01,  9.44425225e-01, -3.44097543e+00,
#         5.03159475e+00,  1.55748820e+00,  4.31927109e+00, -4.90492439e+00,
#         9.02087033e-01, -2.58305717e+00, -2.04735541e+00,  7.07586288e+00,
#        -2.21694398e+00,  1.37626863e+00,  1.26626766e+00,  2.63603091e+00,
#         4.08494091e+00,  3.53242612e+00, -2.71368241e+00,  8.37720335e-01,
#         1.31129217e+00,  2.42056489e+00, -2.86255169e+00,  5.89362323e-01,
#        -2.12250662e+00,  2.64504135e-01, -6.97780788e-01, -6.98449969e-01,
#         2.63015079e+00,  1.63217795e+00,  2.86665738e-01, -3.14404798e+00,
#         2.27669811e+00,  4.86376238e+00, -2.50558043e+00,  2.75914145e+00,
#         2.42352533e+00,  3.56686354e+00,  1.27518678e+00, -3.04664850e+00,
#        -2.60007668e+00,  6.48449719e-01,  2.08892274e+00,  7.95347214e+00,
#         2.31967402e+00,  2.94543862e+00, -5.70481718e-01, -2.74061394e+00,
#        -2.80640292e+00, -2.69794011e+00,  7.46370363e+00, -1.77172923e+00,
#         2.69260311e+00,  2.40334749e+00,  1.12645078e+00,  2.37163067e+00,
#         1.03222370e+00, -1.17479253e+00,  2.89518595e+00,  7.95408154e+00,
#         4.35833311e+00,  1.09465051e+00, -2.50175881e+00, -3.28880548e+00,
#         1.53989410e+00,  4.40511990e+00,  1.75046599e+00,  3.87328339e+00,
#         3.08404541e+00,  3.38038826e+00, -1.37121677e+00,  5.64687014e+00,
#         4.46130133e+00,  3.68490338e+00, -1.72994018e-01, -3.97904706e+00,
#         4.43926764e+00,  3.31233311e+00,  1.74317265e+00, -1.46451092e+00,
#         3.04532671e+00, -2.93763924e+00,  7.46654844e+00, -1.31173873e+00,
#         5.88323736e+00, -1.48938012e+00,  2.01948404e+00,  4.48908001e-01,
#         3.13413215e+00,  3.07225633e+00, -7.06184506e-01,  6.79911852e+00,
#         2.70590997e+00, -3.85698390e+00,  3.35125327e+00,  1.80834973e+00,
#         3.69883180e+00,  1.79265499e+00, -8.12089741e-02,  3.20901990e+00,
#        -2.41779995e+00, -3.96766812e-02,  3.82433438e+00, -8.95820037e-02,
#         1.65590644e+00,  2.90232563e+00, -1.63374364e+00,  2.21470332e+00,
#         4.71305758e-01,  2.92862105e+00, -2.72947884e+00, -2.61002827e+00,
#         4.33934164e+00, -3.20572782e+00, -3.01318455e+00, -8.07178691e-02,
#         4.54090309e+00,  9.55266058e-01, -5.77605295e+00,  1.12818110e+00,
#         1.79031134e+00,  4.03659821e+00,  4.29765642e-01], dtype=float32)

# %%
myCanvas = np.zeros(( 5000,5000,3  ))

# %%
plt.imshow(myCanvas)

# %%
x = xy[:,0].copy()
y = xy[:,1].copy()

# normalise the x values to be between -1 and +1:
x *= (1/np.max(  abs(x)   )) 
# shift them so they are between 0 and 2
x += 1
x *= 2300

y *= (1/np.max(  abs(y)   )) 
y += 1
y *= 2300

# %%
plt.scatter(x,y)

# %%
for i in tqdm.tqdm(range ( len ( allList ))):
    px = int(x[i])
    py = int(y[i])
    
    imr = transform.resize( io.imread( allList[i] ) , (128,128,3))
    myCanvas[px:px+128,py:py+128] = imr
# Out:
#   0%|          | 0/287 [00:00<?, ?it/s]/home/impett/anaconda3/envs/esu2018/lib/python3.5/site-packages/skimage/transform/_warps.py:105: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /home/impett/anaconda3/envs/esu2018/lib/python3.5/site-packages/skimage/transform/_warps.py:110: UserWarning: Anti-aliasing will be enabled by default in skimage 0.15 to avoid aliasing artifacts when down-sampling images.
#   warn("Anti-aliasing will be enabled by default in skimage 0.15 to "
# 100%|██████████| 287/287 [00:05<00:00, 51.11it/s]

# %%
io.imsave('testOutput.jpg',myCanvas)
# Out:
# /home/impett/anaconda3/envs/esu2018/lib/python3.5/site-packages/skimage/util/dtype.py:130: UserWarning: Possible precision loss when converting from float64 to uint8
#   .format(dtypeobj_in, dtypeobj_out))
